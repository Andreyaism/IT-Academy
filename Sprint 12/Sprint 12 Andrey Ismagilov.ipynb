# %% [markdown]
# ## Tarea S12.01. APIS REST

# %% [markdown]
# ### *Andrey Ismagilov*
# ### *Fecha 12/02/2026*

# %%
import pandas as pd
import requests
from requests.exceptions import HTTPError
import json

# %% [markdown]
# ### **Nivel 1**

# %% [markdown]
# ### **Ejercicio 1.**
# ###  Consulta la API pública JSONPlaceholder utilizando el método GET para obtener:

# %%
url = 'https://jsonplaceholder.typicode.com/'

# Comprobamos que existe la pagina web de "url"
try:
    r = requests.get(url)
    r.raise_for_status()
except HTTPError as http_err:
    print(f"HTTP error se ha producido: {http_err}")
except Exception as err:
    print(f"Se ha producido otro error: {err}")
else:
    print("Exito.")
# Out:
# Exito.

# %% [markdown]
# - ##### Lista de publicaciones (/posts)

# %%
url_posts = 'https://jsonplaceholder.typicode.com/posts'
r_posts = requests.get(url_posts)
lista_posts = r_posts.json()
lista_posts[:3]
# Out:
# [{'userId': 1,
#   'id': 1,
#   'title': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit',
#   'body': 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto'},
#  {'userId': 1,
#   'id': 2,
#   'title': 'qui est esse',
#   'body': 'est rerum tempore vitae\nsequi sint nihil reprehenderit dolor beatae ea dolores neque\nfugiat blanditiis voluptate porro vel nihil molestiae ut reiciendis\nqui aperiam non debitis possimus qui neque nisi nulla'},
#  {'userId': 1,
#   'id': 3,
#   'title': 'ea molestias quasi exercitationem repellat qui ipsa sit aut',
#   'body': 'et iusto sed quo iure\nvoluptatem occaecati omnis eligendi aut ad\nvoluptatem doloribus vel accusantium quis pariatur\nmolestiae porro eius odio et labore et velit aut'}]

# %% [markdown]
# - ##### Lista de usuarios (/users)

# %%
url_users = 'https://jsonplaceholder.typicode.com/users'
r_users = requests.get(url_users)
lista_users = r_users.json()
lista_users[:3]
# Out:
# [{'id': 1,
#   'name': 'Leanne Graham',
#   'username': 'Bret',
#   'email': 'Sincere@april.biz',
#   'address': {'street': 'Kulas Light',
#    'suite': 'Apt. 556',
#    'city': 'Gwenborough',
#    'zipcode': '92998-3874',
#    'geo': {'lat': '-37.3159', 'lng': '81.1496'}},
#   'phone': '1-770-736-8031 x56442',
#   'website': 'hildegard.org',
#   'company': {'name': 'Romaguera-Crona',
#    'catchPhrase': 'Multi-layered client-server neural-net',
#    'bs': 'harness real-time e-markets'}},
#  {'id': 2,
#   'name': 'Ervin Howell',
#   'username': 'Antonette',
#   'email': 'Shanna@melissa.tv',
#   'address': {'street': 'Victor Plains',
#    'suite': 'Suite 879',
#    'city': 'Wisokyburgh',
#    'zipcode': '90566-7771',
#    'geo': {'lat': '-43.9509', 'lng': '-34.4618'}},
#   'phone': '010-692-6593 x09125',
#   'website': 'anastasia.net',
#   'company': {'name': 'Deckow-Crist',
#    'catchPhrase': 'Proactive didactic contingency',
#    'bs': 'synergize scalable supply-chains'}},
#  {'id': 3,
#   'name': 'Clementine Bauch',
#   'username': 'Samantha',
#   'email': 'Nathan@yesenia.net',
#   'address': {'street': 'Douglas Extension',
#    'suite': 'Suite 847',
#    'city': 'McKenziehaven',
#    'zipcode': '59590-4157',
#    'geo': {'lat': '-68.6102', 'lng': '-47.0653'}},
#   'phone': '1-463-123-4447',
#   'website': 'ramiro.info',
#   'company': {'name': 'Romaguera-Jacobson',
#    'catchPhrase': 'Face to face bifurcated interface',
#    'bs': 'e-enable strategic applications'}}]

# %% [markdown]
# - ##### Lista de tareas (/todos)

# %%
url_todos = 'https://jsonplaceholder.typicode.com/todos'
r_todos = requests.get(url_todos)
lista_todos = r_todos.json()
lista_todos[:3]
# Out:
# [{'userId': 1, 'id': 1, 'title': 'delectus aut autem', 'completed': False},
#  {'userId': 1,
#   'id': 2,
#   'title': 'quis ut nam facilis et officia qui',
#   'completed': False},
#  {'userId': 1, 'id': 3, 'title': 'fugiat veniam minus', 'completed': False}]

# %% [markdown]
# ### **Ejercicio 2.**
# ###  Muestra por pantalla:
# ### - La cantidad total de cada recurso.
# ### - El código de estado de cada petición.

# %%
print(f'Recurso POSTS: {url_posts}')
print(f'Cantitad: {len(lista_posts)}')
print(f'Códico de estado: {r_posts.status_code}')


print(f'Recurso USERS: {url_users}')
print(f'Cantitad: {len(lista_users)}')
print(f'Códico de estado: {r_users.status_code}')

print(f'Recurso TODOS: {url_todos}')
print(f'Cantitad: {len(lista_todos)}')
print(f'Códico de estado: {r_todos.status_code}')
# Out:
# Recurso POSTS: https://jsonplaceholder.typicode.com/posts
# Cantitad: 100
# Códico de estado: 200
# Recurso USERS: https://jsonplaceholder.typicode.com/users
# Cantitad: 10
# Códico de estado: 200
# Recurso TODOS: https://jsonplaceholder.typicode.com/todos
# Cantitad: 200
# Códico de estado: 200

# %% [markdown]
# ### **Ejercicio 3.**
# ###  Realiza una petición a una publicación inexistente para obtener un error 404 y muestra el código de estado recibido.

# %%
url_not_exists = url + '/not_exist'

r_not_exist = requests.get(url_not_exists)
print(f'Recurso NOT_exist: {url_not_exists}')
print(f'Códico de estado: {r_not_exist.status_code}')
# Out:
# Recurso NOT_exist: https://jsonplaceholder.typicode.com//not_exist
# Códico de estado: 404

# %% [markdown]
# ### **Ejercicio 4.**
# ### Realiza una petición POST para crear una nueva publicación ficticia. Incluye el título, el cuerpo del mensaje y un userId.

# %% [markdown]
# ##### Obtenemos el número de publicaciones del recurso POSTS

# %%
r_posts = requests.get(url_posts)
lista_posts = r_posts.json()
num_de_public = len(lista_posts)

# %% [markdown]
# ##### Creamos  la nueva publicación ficticia

# %%
public_ficticia = {
    'userId': 1,
    'id': num_de_public + 1,
    'title': 'title fictitious AI',
    'body': 'message fictitious AI'
    }

r_de_post = requests.post(url_posts, data = public_ficticia)

if r_de_post.status_code == 201:
    print('Exito.')
    print(f'Codico de estado: {r_de_post.status_code}')
    print('Cuerpo de publicación: \n', r_de_post.request.body)
else:
    print(f'Error. Codico de error: {r_de_post.status_code}')
# Out:
# Exito.
# Codico de estado: 201
# Cuerpo de publicación:
#  userId=1&id=101&title=title+fictitious+AI&body=message+fictitious+AI

# %% [markdown]
# ### **Ejercicio 5.**
# ###  Realiza una petición PATCH para modificar parcialmente una publicación existente.

# %%
id_post_a_modificar = 1

url_a_modificar = url_posts + '/' + str(id_post_a_modificar)

public_ficticia_modificada = {
    "body": "Modificada por PATCH"
  }

r_de_patch = requests.patch(url_a_modificar, data = public_ficticia_modificada)

if r_de_patch.status_code == 200:
  print('Modificado.')
  print(f'Codico de estado: {r_de_patch.status_code}')
else:
  print(f'Error. Codico de error: {r_de_patch.status_code}')
# Out:
# Modificado.
# Codico de estado: 200

# %% [markdown]
# ### **Ejercicio 6.**
# ###  Haz una petición DELETE sobre una publicación.

# %%
id_post_a_eliminar = 2

url_a_eliminar = url_posts + '/' + str(id_post_a_eliminar)

r_de_eliminar = requests.delete(url_a_eliminar)

if r_de_eliminar.status_code == 200:
  print('Modificado.')
  print(f'Codico de estado: {r_de_eliminar.status_code}')
else:
  print(f'Error. Codico de error: {r_de_eliminar.status_code}')
# Out:
# Modificado.
# Codico de estado: 200

# %% [markdown]
# ### **Nivel 2**

# %% [markdown]
# ### **Ejercicio 1.**
# ###  Explora el repositorio de Public APIs y elige una API que permita realizar peticiones GET.

# %% [markdown]
# He eligido API **Aviationstack** que proporciona acceso a los datos globales de aviación y estado de vuelos en tiempo real.

# %% [markdown]
# ### **Ejercicio 2.**

# %% [markdown]
# - ##### Revisa la sección de endpoints disponibles. En un markdown, apunta al menos dos endpoints diferentes.

# %% [markdown]
# API **Aviationstack** cuenta 11 endpoints incluido los datos de vuelos, rutas, aeropuertos, aerolínias, horarios de vuelos etc.

# %% [markdown]
# - #### Comprueba si ofrece filtros o parámetros opcionales interesantes. En un markdown, anótalos.

# %% [markdown]
# El API permite filtrar los datos por varias parámetros.
#
# Por ejemplo en el endpoint FLIGHT se puede pasar un codico de aerolinia, un nombre de aerolinia, una fecha de vuelos buscados, un número de vuelo, estado de vuelo y mucho más.
#
# Hay un parametro interesante llamado **callback** que permite pasar la respuesta de peticion en formato JSON a una función predefinida

# %% [markdown]
# Ademas el parametro **lang** permite traducir los nombres de aeropuertos, ciudades y países a muchas idiomas.

# %% [markdown]
# Algunos endpoints de **Aviationstack** proporcionan tambien las funciones de autocompletar de aplicación de usuario. Para obtener sugerencias de autocompletar se agrega el parámetro **search** a la URL de petición de la API y le asigna a un término de busqueda.

# %% [markdown]
# ### **Ejercicio 3.**

# %% [markdown]
# #### Haz una petición GET sencilla.

# %% [markdown]
# - #### Muestra el código de estado de la respuesta.

# %%
access_key = '22c8207d1c76c955d2f67e558ebf42bd'

endpoint_flights = 'https://api.aviationstack.com/v1/flights'

querystring = {
    'access_key': access_key,
    'airline_iata': 'VY' # `por ejemplo Vueling
    }

headers = {"Accept": "application/json"}

r_vuelos = requests.get(endpoint_flights, headers=headers, params=querystring)

if r_vuelos.status_code == 200:
    print('Éxito.')
    print(f'Codico de estado: {r_vuelos.status_code}')
else:
    print(f'Error. Codico de error: {r_vuelos.status_code}')

r_vuelos.json()
# Out:
# Éxito.
# Codico de estado: 200
# {'pagination': {'limit': 100, 'offset': 0, 'count': 100, 'total': 2064},
#  'data': [{'flight_date': '2026-02-17',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Ben Gurion International',
#     'timezone': 'Asia/Jerusalem',
#     'iata': 'TLV',
#     'icao': 'LLBG',
#     'terminal': '3',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2026-02-17T06:00:00+00:00',
#     'estimated': '2026-02-17T06:00:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4S',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-17T10:30:00+00:00',
#     'delay': 15,
#     'estimated': None,
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5284',
#     'iata': 'VY5284',
#     'icao': 'VLG5284',
#     'codeshared': {'airline_name': 'iberia express',
#      'airline_iata': 'i2',
#      'airline_icao': 'ibs',
#      'flight_number': '1874',
#      'flight_iata': 'i21874',
#      'flight_icao': 'ibs1874'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '347247'},
#    'live': None},
#   {'flight_date': '2026-02-17',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'El Prat De Llobregat',
#     'timezone': 'Europe/Madrid',
#     'iata': 'BCN',
#     'icao': 'LEBL',
#     'terminal': '1',
#     'gate': 'D',
#     'delay': None,
#     'scheduled': '2026-02-17T01:30:00+00:00',
#     'estimated': '2026-02-17T01:30:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Ezeiza Ministro Pistarini',
#     'timezone': 'America/Argentina/Buenos_Aires',
#     'iata': 'EZE',
#     'icao': 'SAEZ',
#     'terminal': 'IA',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-17T11:10:00+00:00',
#     'delay': None,
#     'estimated': None,
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '9781',
#     'iata': 'VY9781',
#     'icao': 'VLG9781',
#     'codeshared': {'airline_name': 'level',
#      'airline_iata': 'll',
#      'airline_icao': 'lvl',
#      'flight_number': '2601',
#      'flight_iata': 'll2601',
#      'flight_icao': 'lvl2601'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '346605'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2026-02-16T23:00:00+00:00',
#     'estimated': '2026-02-16T23:00:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Lisbon Portela',
#     'timezone': 'Europe/Lisbon',
#     'iata': 'LIS',
#     'icao': 'LPPT',
#     'terminal': '1',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T23:25:00+00:00',
#     'delay': 18,
#     'estimated': None,
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5219',
#     'iata': 'VY5219',
#     'icao': 'VLG5219',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '539',
#      'flight_iata': 'ib539',
#      'flight_icao': 'ibe539'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '3423C4'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Blaise Diagne International Airport\r\n',
#     'timezone': None,
#     'iata': 'DSS',
#     'icao': 'GOBD',
#     'terminal': None,
#     'gate': None,
#     'delay': 1,
#     'scheduled': '2026-02-16T20:35:00+00:00',
#     'estimated': '2026-02-16T20:35:00+00:00',
#     'actual': '2026-02-16T20:53:00+00:00',
#     'estimated_runway': '2026-02-16T20:53:00+00:00',
#     'actual_runway': '2026-02-16T20:53:00+00:00'},
#    'arrival': {'airport': 'El Prat De Llobregat',
#     'timezone': 'Europe/Madrid',
#     'iata': 'BCN',
#     'icao': 'LEBL',
#     'terminal': 'T1',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-17T02:15:00+00:00',
#     'delay': 18,
#     'estimated': '2026-02-17T02:16:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '7887',
#     'iata': 'VY7887',
#     'icao': 'VLG7887',
#     'codeshared': None},
#    'aircraft': {'registration': 'EC-MFN',
#     'iata': 'A320',
#     'icao': 'A320',
#     'icao24': '344697'},
#    'live': {'updated': '2026-02-16T21:41:44+00:00',
#     'latitude': 19.7422,
#     'longitude': -13.979,
#     'altitude': 10668,
#     'direction': 28,
#     'speed_horizontal': 900.072,
#     'speed_vertical': 0,
#     'is_ground': False}},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2026-02-16T21:40:00+00:00',
#     'estimated': '2026-02-16T21:40:00+00:00',
#     'actual': '2026-02-16T22:13:00+00:00',
#     'estimated_runway': '2026-02-16T22:13:00+00:00',
#     'actual_runway': '2026-02-16T22:13:00+00:00'},
#    'arrival': {'airport': 'Charles De Gaulle',
#     'timezone': 'Europe/Paris',
#     'iata': 'CDG',
#     'icao': 'LFPG',
#     'terminal': '3',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T23:50:00+00:00',
#     'delay': None,
#     'estimated': '2026-02-16T23:45:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5250',
#     'iata': 'VY5250',
#     'icao': 'VLG5250',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '591',
#      'flight_iata': 'ib591',
#      'flight_icao': 'ibe591'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '34134D'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4S',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2026-02-16T20:50:00+00:00',
#     'estimated': '2026-02-16T20:50:00+00:00',
#     'actual': '2026-02-16T21:07:00+00:00',
#     'estimated_runway': '2026-02-16T21:07:00+00:00',
#     'actual_runway': '2026-02-16T21:07:00+00:00'},
#    'arrival': {'airport': 'Heathrow',
#     'timezone': 'Europe/London',
#     'iata': 'LHR',
#     'icao': 'EGLL',
#     'terminal': '5',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T22:10:00+00:00',
#     'delay': 18,
#     'estimated': '2026-02-16T21:58:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '9547',
#     'iata': 'VY9547',
#     'icao': 'VLG9547',
#     'codeshared': {'airline_name': 'british airways',
#      'airline_iata': 'ba',
#      'airline_icao': 'baw',
#      'flight_number': '469',
#      'flight_iata': 'ba469',
#      'flight_icao': 'baw469'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '4009C5'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Blagnac',
#     'timezone': 'Europe/Paris',
#     'iata': 'TLS',
#     'icao': 'LFBO',
#     'terminal': None,
#     'gate': None,
#     'delay': 2,
#     'scheduled': '2026-02-16T20:40:00+00:00',
#     'estimated': '2026-02-16T20:40:00+00:00',
#     'actual': '2026-02-16T21:07:00+00:00',
#     'estimated_runway': '2026-02-16T21:07:00+00:00',
#     'actual_runway': '2026-02-16T21:07:00+00:00'},
#    'arrival': {'airport': 'El Prat De Llobregat',
#     'timezone': 'Europe/Madrid',
#     'iata': 'BCN',
#     'icao': 'LEBL',
#     'terminal': 'T1',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T21:35:00+00:00',
#     'delay': 27,
#     'estimated': '2026-02-16T21:37:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '4084',
#     'iata': 'VY4084',
#     'icao': 'VLG4084',
#     'codeshared': None},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '3424D2'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'St-Exupéry',
#     'timezone': 'Europe/Paris',
#     'iata': 'LYS',
#     'icao': 'LFLL',
#     'terminal': None,
#     'gate': None,
#     'delay': None,
#     'scheduled': '2026-02-16T20:35:00+00:00',
#     'estimated': '2026-02-16T20:35:00+00:00',
#     'actual': '2026-02-16T21:03:00+00:00',
#     'estimated_runway': '2026-02-16T21:03:00+00:00',
#     'actual_runway': '2026-02-16T21:03:00+00:00'},
#    'arrival': {'airport': 'El Prat De Llobregat',
#     'timezone': 'Europe/Madrid',
#     'iata': 'BCN',
#     'icao': 'LEBL',
#     'terminal': 'T1',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T21:55:00+00:00',
#     'delay': 28,
#     'estimated': '2026-02-16T21:54:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '4389',
#     'iata': 'VY4389',
#     'icao': 'VLG4389',
#     'codeshared': None},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '344099'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Heathrow',
#     'timezone': 'Europe/London',
#     'iata': 'LHR',
#     'icao': 'EGLL',
#     'terminal': '5',
#     'gate': 'A8',
#     'delay': 14,
#     'scheduled': '2026-02-16T19:40:00+00:00',
#     'estimated': '2026-02-16T19:40:00+00:00',
#     'actual': '2026-02-16T20:24:00+00:00',
#     'estimated_runway': '2026-02-16T20:24:00+00:00',
#     'actual_runway': '2026-02-16T20:24:00+00:00'},
#    'arrival': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4S',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T23:05:00+00:00',
#     'delay': 44,
#     'estimated': '2026-02-16T23:19:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5186',
#     'iata': 'VY5186',
#     'icao': 'VLG5186',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '726',
#      'flight_iata': 'ib726',
#      'flight_icao': 'ibe726'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '3472CC'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Marseille Provence Airport',
#     'timezone': 'Europe/Paris',
#     'iata': 'MRS',
#     'icao': 'LFML',
#     'terminal': None,
#     'gate': None,
#     'delay': None,
#     'scheduled': '2026-02-16T21:10:00+00:00',
#     'estimated': '2026-02-16T21:10:00+00:00',
#     'actual': '2026-02-16T21:11:00+00:00',
#     'estimated_runway': '2026-02-16T21:11:00+00:00',
#     'actual_runway': '2026-02-16T21:11:00+00:00'},
#    'arrival': {'airport': 'El Prat De Llobregat',
#     'timezone': 'Europe/Madrid',
#     'iata': 'BCN',
#     'icao': 'LEBL',
#     'terminal': 'T1',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T22:15:00+00:00',
#     'delay': 1,
#     'estimated': '2026-02-16T21:50:00+00:00',
#     'actual': '2026-02-16T21:55:00+00:00',
#     'estimated_runway': '2026-02-16T21:55:00+00:00',
#     'actual_runway': '2026-02-16T21:55:00+00:00'},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '4154',
#     'iata': 'VY4154',
#     'icao': 'VLG4154',
#     'codeshared': None},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '3444D1'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2026-02-16T20:40:00+00:00',
#     'estimated': '2026-02-16T20:40:00+00:00',
#     'actual': '2026-02-16T21:01:00+00:00',
#     'estimated_runway': '2026-02-16T21:01:00+00:00',
#     'actual_runway': '2026-02-16T21:01:00+00:00'},
#    'arrival': {'airport': 'Agoncillo',
#     'timezone': 'Europe/Madrid',
#     'iata': 'RJL',
#     'icao': 'LERJ',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T21:55:00+00:00',
#     'delay': 22,
#     'estimated': '2026-02-16T21:48:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5622',
#     'iata': 'VY5622',
#     'icao': 'VLG5622',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '2222',
#      'flight_iata': 'ib2222',
#      'flight_icao': 'ibe2222'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '344307'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4',
#     'gate': None,
#     'delay': 4,
#     'scheduled': '2026-02-16T21:35:00+00:00',
#     'estimated': '2026-02-16T21:35:00+00:00',
#     'actual': '2026-02-16T22:11:00+00:00',
#     'estimated_runway': '2026-02-16T22:11:00+00:00',
#     'actual_runway': '2026-02-16T22:11:00+00:00'},
#    'arrival': {'airport': 'El Prat De Llobregat',
#     'timezone': 'Europe/Madrid',
#     'iata': 'BCN',
#     'icao': 'LEBL',
#     'terminal': '1',
#     'gate': None,
#     'baggage': '15',
#     'scheduled': '2026-02-16T22:50:00+00:00',
#     'delay': 37,
#     'estimated': '2026-02-16T22:54:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5091',
#     'iata': 'VY5091',
#     'icao': 'VLG5091',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '427',
#      'flight_iata': 'ib427',
#      'flight_icao': 'ibe427'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '347344'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Heathrow',
#     'timezone': 'Europe/London',
#     'iata': 'LHR',
#     'icao': 'EGLL',
#     'terminal': '5',
#     'gate': 'A21',
#     'delay': None,
#     'scheduled': '2026-02-16T19:15:00+00:00',
#     'estimated': '2026-02-16T19:15:00+00:00',
#     'actual': '2026-02-16T19:48:00+00:00',
#     'estimated_runway': '2026-02-16T19:48:00+00:00',
#     'actual_runway': '2026-02-16T19:48:00+00:00'},
#    'arrival': {'airport': 'El Prat De Llobregat',
#     'timezone': 'Europe/Madrid',
#     'iata': 'BCN',
#     'icao': 'LEBL',
#     'terminal': '1',
#     'gate': None,
#     'baggage': '13',
#     'scheduled': '2026-02-16T22:30:00+00:00',
#     'delay': 33,
#     'estimated': '2026-02-16T22:22:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '9570',
#     'iata': 'VY9570',
#     'icao': 'VLG9570',
#     'codeshared': {'airline_name': 'british airways',
#      'airline_iata': 'ba',
#      'airline_icao': 'baw',
#      'flight_number': '492',
#      'flight_iata': 'ba492',
#      'flight_icao': 'baw492'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '407B8F'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2026-02-16T19:50:00+00:00',
#     'estimated': '2026-02-16T19:50:00+00:00',
#     'actual': '2026-02-16T20:31:00+00:00',
#     'estimated_runway': '2026-02-16T20:31:00+00:00',
#     'actual_runway': '2026-02-16T20:31:00+00:00'},
#    'arrival': {'airport': 'Frankfurt International Airport',
#     'timezone': 'Europe/Berlin',
#     'iata': 'FRA',
#     'icao': 'EDDF',
#     'terminal': '2',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T22:35:00+00:00',
#     'delay': 42,
#     'estimated': '2026-02-16T22:32:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5520',
#     'iata': 'VY5520',
#     'icao': 'VLG5520',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '1331',
#      'flight_iata': 'ib1331',
#      'flight_icao': 'ibe1331'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '345250'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Heathrow',
#     'timezone': 'Europe/London',
#     'iata': 'LHR',
#     'icao': 'EGLL',
#     'terminal': '5',
#     'gate': 'A8',
#     'delay': None,
#     'scheduled': '2026-02-16T19:05:00+00:00',
#     'estimated': '2026-02-16T19:05:00+00:00',
#     'actual': '2026-02-16T19:43:00+00:00',
#     'estimated_runway': '2026-02-16T19:43:00+00:00',
#     'actual_runway': '2026-02-16T19:43:00+00:00'},
#    'arrival': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4S',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T22:30:00+00:00',
#     'delay': 38,
#     'estimated': None,
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5187',
#     'iata': 'VY5187',
#     'icao': 'VLG5187',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '724',
#      'flight_iata': 'ib724',
#      'flight_icao': 'ibe724'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '345692'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Heathrow',
#     'timezone': 'Europe/London',
#     'iata': 'LHR',
#     'icao': 'EGLL',
#     'terminal': '5',
#     'gate': 'C56',
#     'delay': None,
#     'scheduled': '2026-02-16T18:45:00+00:00',
#     'estimated': '2026-02-16T18:45:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4S',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T22:10:00+00:00',
#     'delay': 37,
#     'estimated': None,
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5227',
#     'iata': 'VY5227',
#     'icao': 'VLG5227',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '722',
#      'flight_iata': 'ib722',
#      'flight_icao': 'ibe722'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '3444C4'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2026-02-16T20:00:00+00:00',
#     'estimated': '2026-02-16T20:00:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'El Prat De Llobregat',
#     'timezone': 'Europe/Madrid',
#     'iata': 'BCN',
#     'icao': 'LEBL',
#     'terminal': '1',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T21:20:00+00:00',
#     'delay': 96,
#     'estimated': None,
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5079',
#     'iata': 'VY5079',
#     'icao': 'VLG5079',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '425',
#      'flight_iata': 'ib425',
#      'flight_icao': 'ibe425'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '347288'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'El Prat De Llobregat',
#     'timezone': 'Europe/Madrid',
#     'iata': 'BCN',
#     'icao': 'LEBL',
#     'terminal': '1',
#     'gate': 'D',
#     'delay': None,
#     'scheduled': '2026-02-16T23:35:00+00:00',
#     'estimated': '2026-02-16T23:35:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Arturo Merino Benitez',
#     'timezone': 'America/Santiago',
#     'iata': 'SCL',
#     'icao': 'SCEL',
#     'terminal': '2',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-17T10:10:00+00:00',
#     'delay': 13,
#     'estimated': None,
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '9785',
#     'iata': 'VY9785',
#     'icao': 'VLG9785',
#     'codeshared': {'airline_name': 'level',
#      'airline_iata': 'll',
#      'airline_icao': 'lvl',
#      'flight_number': '2605',
#      'flight_iata': 'll2605',
#      'flight_icao': 'lvl2605'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '34718D'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'El Prat De Llobregat',
#     'timezone': 'Europe/Madrid',
#     'iata': 'BCN',
#     'icao': 'LEBL',
#     'terminal': '1',
#     'gate': 'A06',
#     'delay': None,
#     'scheduled': '2026-02-16T21:15:00+00:00',
#     'estimated': '2026-02-16T21:15:00+00:00',
#     'actual': '2026-02-16T21:32:00+00:00',
#     'estimated_runway': '2026-02-16T21:32:00+00:00',
#     'actual_runway': '2026-02-16T21:32:00+00:00'},
#    'arrival': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4S',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T22:40:00+00:00',
#     'delay': 18,
#     'estimated': '2026-02-16T22:28:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5100',
#     'iata': 'VY5100',
#     'icao': 'VLG5100',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '424',
#      'flight_iata': 'ib424',
#      'flight_icao': 'ibe424'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '34224E'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4',
#     'gate': None,
#     'delay': 1,
#     'scheduled': '2026-02-16T19:40:00+00:00',
#     'estimated': '2026-02-16T19:40:00+00:00',
#     'actual': '2026-02-16T20:08:00+00:00',
#     'estimated_runway': '2026-02-16T20:08:00+00:00',
#     'actual_runway': '2026-02-16T20:08:00+00:00'},
#    'arrival': {'airport': 'Schiphol',
#     'timezone': 'Europe/Amsterdam',
#     'iata': 'AMS',
#     'icao': 'EHAM',
#     'terminal': '1',
#     'gate': 'C10',
#     'baggage': '4',
#     'scheduled': '2026-02-16T22:20:00+00:00',
#     'delay': 1,
#     'estimated': '2026-02-16T22:22:00+00:00',
#     'actual': '2026-02-16T22:21:00+00:00',
#     'estimated_runway': '2026-02-16T22:21:00+00:00',
#     'actual_runway': '2026-02-16T22:21:00+00:00'},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5162',
#     'iata': 'VY5162',
#     'icao': 'VLG5162',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '739',
#      'flight_iata': 'ib739',
#      'flight_icao': 'ibe739'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '346316'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'El Prat De Llobregat',
#     'timezone': 'Europe/Madrid',
#     'iata': 'BCN',
#     'icao': 'LEBL',
#     'terminal': '1',
#     'gate': 'D14',
#     'delay': None,
#     'scheduled': '2026-02-16T21:00:00+00:00',
#     'estimated': '2026-02-16T21:00:00+00:00',
#     'actual': '2026-02-16T21:21:00+00:00',
#     'estimated_runway': '2026-02-16T21:21:00+00:00',
#     'actual_runway': '2026-02-16T21:21:00+00:00'},
#    'arrival': {'airport': 'Heathrow',
#     'timezone': 'Europe/London',
#     'iata': 'LHR',
#     'icao': 'EGLL',
#     'terminal': '5',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T22:20:00+00:00',
#     'delay': 22,
#     'estimated': '2026-02-16T22:11:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '9569',
#     'iata': 'VY9569',
#     'icao': 'VLG9569',
#     'codeshared': {'airline_name': 'british airways',
#      'airline_iata': 'ba',
#      'airline_icao': 'baw',
#      'flight_number': '491',
#      'flight_iata': 'ba491',
#      'flight_icao': 'baw491'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '407462'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4S',
#     'gate': None,
#     'delay': 5,
#     'scheduled': '2026-02-16T19:25:00+00:00',
#     'estimated': '2026-02-16T19:25:00+00:00',
#     'actual': '2026-02-16T19:45:00+00:00',
#     'estimated_runway': '2026-02-16T19:45:00+00:00',
#     'actual_runway': '2026-02-16T19:45:00+00:00'},
#    'arrival': {'airport': 'Heathrow',
#     'timezone': 'Europe/London',
#     'iata': 'LHR',
#     'icao': 'EGLL',
#     'terminal': '5',
#     'gate': None,
#     'baggage': '10',
#     'scheduled': '2026-02-16T20:45:00+00:00',
#     'delay': 5,
#     'estimated': '2026-02-16T20:50:00+00:00',
#     'actual': '2026-02-16T20:50:00+00:00',
#     'estimated_runway': '2026-02-16T20:50:00+00:00',
#     'actual_runway': '2026-02-16T20:50:00+00:00'},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '9543',
#     'iata': 'VY9543',
#     'icao': 'VLG9543',
#     'codeshared': {'airline_name': 'british airways',
#      'airline_iata': 'ba',
#      'airline_icao': 'baw',
#      'flight_number': '467',
#      'flight_iata': 'ba467',
#      'flight_icao': 'baw467'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '406BBB'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'landed',
#    'departure': {'airport': 'El Prat De Llobregat',
#     'timezone': 'Europe/Madrid',
#     'iata': 'BCN',
#     'icao': 'LEBL',
#     'terminal': '1',
#     'gate': 'D08',
#     'delay': 12,
#     'scheduled': '2026-02-16T20:00:00+00:00',
#     'estimated': '2026-02-16T20:00:00+00:00',
#     'actual': '2026-02-16T20:14:00+00:00',
#     'estimated_runway': '2026-02-16T20:14:00+00:00',
#     'actual_runway': '2026-02-16T20:14:00+00:00'},
#    'arrival': {'airport': 'Heathrow',
#     'timezone': 'Europe/London',
#     'iata': 'LHR',
#     'icao': 'EGLL',
#     'terminal': '5',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T21:20:00+00:00',
#     'delay': 12,
#     'estimated': '2026-02-16T21:27:00+00:00',
#     'actual': '2026-02-16T21:32:00+00:00',
#     'estimated_runway': '2026-02-16T21:32:00+00:00',
#     'actual_runway': '2026-02-16T21:32:00+00:00'},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '9565',
#     'iata': 'VY9565',
#     'icao': 'VLG9565',
#     'codeshared': {'airline_name': 'british airways',
#      'airline_iata': 'ba',
#      'airline_icao': 'baw',
#      'flight_number': '487',
#      'flight_iata': 'ba487',
#      'flight_icao': 'baw487'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '400A7D'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2026-02-16T19:40:00+00:00',
#     'estimated': '2026-02-16T19:40:00+00:00',
#     'actual': '2026-02-16T19:52:00+00:00',
#     'estimated_runway': '2026-02-16T19:52:00+00:00',
#     'actual_runway': '2026-02-16T19:52:00+00:00'},
#    'arrival': {'airport': 'Lisbon Portela',
#     'timezone': 'Europe/Lisbon',
#     'iata': 'LIS',
#     'icao': 'LPPT',
#     'terminal': '1',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T20:05:00+00:00',
#     'delay': 12,
#     'estimated': '2026-02-16T19:54:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5748',
#     'iata': 'VY5748',
#     'icao': 'VLG5748',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '1145',
#      'flight_iata': 'ib1145',
#      'flight_icao': 'ibe1145'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '3451D9'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Lisbon Portela',
#     'timezone': 'Europe/Lisbon',
#     'iata': 'LIS',
#     'icao': 'LPPT',
#     'terminal': '1',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2026-02-16T20:45:00+00:00',
#     'estimated': '2026-02-16T20:45:00+00:00',
#     'actual': '2026-02-16T21:14:00+00:00',
#     'estimated_runway': '2026-02-16T21:14:00+00:00',
#     'actual_runway': '2026-02-16T21:14:00+00:00'},
#    'arrival': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4S',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T23:10:00+00:00',
#     'delay': 30,
#     'estimated': '2026-02-16T23:06:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5749',
#     'iata': 'VY5749',
#     'icao': 'VLG5749',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '1146',
#      'flight_iata': 'ib1146',
#      'flight_icao': 'ibe1146'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '3451D9'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2026-02-16T19:10:00+00:00',
#     'estimated': '2026-02-16T19:10:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'El Prat De Llobregat',
#     'timezone': 'Europe/Madrid',
#     'iata': 'BCN',
#     'icao': 'LEBL',
#     'terminal': '1',
#     'gate': None,
#     'baggage': '15',
#     'scheduled': '2026-02-16T20:25:00+00:00',
#     'delay': 56,
#     'estimated': None,
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5063',
#     'iata': 'VY5063',
#     'icao': 'VLG5063',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '423',
#      'flight_iata': 'ib423',
#      'flight_icao': 'ibe423'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '344481'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2026-02-16T22:45:00+00:00',
#     'estimated': '2026-02-16T22:45:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Sur Reina Sofia',
#     'timezone': 'Atlantic/Canary',
#     'iata': 'TFS',
#     'icao': 'GCTS',
#     'terminal': None,
#     'gate': None,
#     'baggage': 'A4',
#     'scheduled': '2026-02-17T00:45:00+00:00',
#     'delay': None,
#     'estimated': None,
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5472',
#     'iata': 'VY5472',
#     'icao': 'VLG5472',
#     'codeshared': {'airline_name': 'iberia express',
#      'airline_iata': 'i2',
#      'airline_icao': 'ibs',
#      'flight_number': '1553',
#      'flight_iata': 'i21553',
#      'flight_icao': 'ibs1553'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '343385'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2026-02-16T22:30:00+00:00',
#     'estimated': '2026-02-16T22:30:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Gran Canaria',
#     'timezone': 'Atlantic/Canary',
#     'iata': 'LPA',
#     'icao': 'GCLP',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-17T00:25:00+00:00',
#     'delay': 13,
#     'estimated': None,
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5411',
#     'iata': 'VY5411',
#     'icao': 'VLG5411',
#     'codeshared': {'airline_name': 'iberia express',
#      'airline_iata': 'i2',
#      'airline_icao': 'ibs',
#      'flight_number': '1631',
#      'flight_iata': 'i21631',
#      'flight_icao': 'ibs1631'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '342188'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Heathrow',
#     'timezone': 'Europe/London',
#     'iata': 'LHR',
#     'icao': 'EGLL',
#     'terminal': '5',
#     'gate': 'A17',
#     'delay': None,
#     'scheduled': '2026-02-16T17:25:00+00:00',
#     'estimated': '2026-02-16T17:25:00+00:00',
#     'actual': '2026-02-16T17:58:00+00:00',
#     'estimated_runway': '2026-02-16T17:58:00+00:00',
#     'actual_runway': '2026-02-16T17:58:00+00:00'},
#    'arrival': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4S',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T20:50:00+00:00',
#     'delay': 33,
#     'estimated': '2026-02-16T20:48:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5181',
#     'iata': 'VY5181',
#     'icao': 'VLG5181',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '720',
#      'flight_iata': 'ib720',
#      'flight_icao': 'ibe720'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '34660B'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Leonardo Da Vinci (Fiumicino)',
#     'timezone': 'Europe/Rome',
#     'iata': 'FCO',
#     'icao': 'LIRF',
#     'terminal': '1',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2026-02-16T20:20:00+00:00',
#     'estimated': '2026-02-16T20:20:00+00:00',
#     'actual': '2026-02-16T20:39:00+00:00',
#     'estimated_runway': '2026-02-16T20:39:00+00:00',
#     'actual_runway': '2026-02-16T20:39:00+00:00'},
#    'arrival': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4S',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T22:55:00+00:00',
#     'delay': 19,
#     'estimated': '2026-02-16T22:49:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5237',
#     'iata': 'VY5237',
#     'icao': 'VLG5237',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '656',
#      'flight_iata': 'ib656',
#      'flight_icao': 'ibe656'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '342091'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Leonardo Da Vinci (Fiumicino)',
#     'timezone': 'Europe/Rome',
#     'iata': 'FCO',
#     'icao': 'LIRF',
#     'terminal': '1',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2026-02-16T19:00:00+00:00',
#     'estimated': '2026-02-16T19:00:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T21:35:00+00:00',
#     'delay': 48,
#     'estimated': None,
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5105',
#     'iata': 'VY5105',
#     'icao': 'VLG5105',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '654',
#      'flight_iata': 'ib654',
#      'flight_icao': 'ibe654'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '346499'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'landed',
#    'departure': {'airport': 'El Prat De Llobregat',
#     'timezone': 'Europe/Madrid',
#     'iata': 'BCN',
#     'icao': 'LEBL',
#     'terminal': '1',
#     'gate': 'A02',
#     'delay': 13,
#     'scheduled': '2026-02-16T18:55:00+00:00',
#     'estimated': '2026-02-16T18:55:00+00:00',
#     'actual': '2026-02-16T19:41:00+00:00',
#     'estimated_runway': '2026-02-16T19:41:00+00:00',
#     'actual_runway': '2026-02-16T19:41:00+00:00'},
#    'arrival': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T20:20:00+00:00',
#     'delay': 13,
#     'estimated': '2026-02-16T20:31:00+00:00',
#     'actual': '2026-02-16T20:33:00+00:00',
#     'estimated_runway': '2026-02-16T20:33:00+00:00',
#     'actual_runway': '2026-02-16T20:33:00+00:00'},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5090',
#     'iata': 'VY5090',
#     'icao': 'VLG5090',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '420',
#      'flight_iata': 'ib420',
#      'flight_icao': 'ibe420'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '347288'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Frankfurt International Airport',
#     'timezone': 'Europe/Berlin',
#     'iata': 'FRA',
#     'icao': 'EDDF',
#     'terminal': '2',
#     'gate': 'D21',
#     'delay': None,
#     'scheduled': '2026-02-16T19:35:00+00:00',
#     'estimated': '2026-02-16T19:35:00+00:00',
#     'actual': '2026-02-16T20:06:00+00:00',
#     'estimated_runway': '2026-02-16T20:06:00+00:00',
#     'actual_runway': '2026-02-16T20:06:00+00:00'},
#    'arrival': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T22:25:00+00:00',
#     'delay': 32,
#     'estimated': '2026-02-16T22:17:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5244',
#     'iata': 'VY5244',
#     'icao': 'VLG5244',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '766',
#      'flight_iata': 'ib766',
#      'flight_icao': 'ibe766'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '34260E'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Lisbon Portela',
#     'timezone': 'Europe/Lisbon',
#     'iata': 'LIS',
#     'icao': 'LPPT',
#     'terminal': '1',
#     'gate': None,
#     'delay': 13,
#     'scheduled': '2026-02-16T18:45:00+00:00',
#     'estimated': '2026-02-16T18:45:00+00:00',
#     'actual': '2026-02-16T19:34:00+00:00',
#     'estimated_runway': '2026-02-16T19:34:00+00:00',
#     'actual_runway': '2026-02-16T19:34:00+00:00'},
#    'arrival': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T21:10:00+00:00',
#     'delay': 13,
#     'estimated': '2026-02-16T21:18:00+00:00',
#     'actual': '2026-02-16T21:23:00+00:00',
#     'estimated_runway': '2026-02-16T21:23:00+00:00',
#     'actual_runway': '2026-02-16T21:23:00+00:00'},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5216',
#     'iata': 'VY5216',
#     'icao': 'VLG5216',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '536',
#      'flight_iata': 'ib536',
#      'flight_icao': 'ibe536'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '3420CC'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Heathrow',
#     'timezone': 'Europe/London',
#     'iata': 'LHR',
#     'icao': 'EGLL',
#     'terminal': '5',
#     'gate': 'A8',
#     'delay': None,
#     'scheduled': '2026-02-16T16:55:00+00:00',
#     'estimated': '2026-02-16T16:55:00+00:00',
#     'actual': '2026-02-16T17:26:00+00:00',
#     'estimated_runway': '2026-02-16T17:26:00+00:00',
#     'actual_runway': '2026-02-16T17:26:00+00:00'},
#    'arrival': {'airport': 'El Prat De Llobregat',
#     'timezone': 'Europe/Madrid',
#     'iata': 'BCN',
#     'icao': 'LEBL',
#     'terminal': '1',
#     'gate': None,
#     'baggage': '14',
#     'scheduled': '2026-02-16T20:05:00+00:00',
#     'delay': 32,
#     'estimated': '2026-02-16T20:01:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '9568',
#     'iata': 'VY9568',
#     'icao': 'VLG9568',
#     'codeshared': {'airline_name': 'british airways',
#      'airline_iata': 'ba',
#      'airline_icao': 'baw',
#      'flight_number': '490',
#      'flight_iata': 'ba490',
#      'flight_icao': 'baw490'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '407462'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2026-02-16T21:50:00+00:00',
#     'estimated': '2026-02-16T21:50:00+00:00',
#     'actual': '2026-02-16T22:14:00+00:00',
#     'estimated_runway': '2026-02-16T22:14:00+00:00',
#     'actual_runway': '2026-02-16T22:14:00+00:00'},
#    'arrival': {'airport': 'Leonardo Da Vinci (Fiumicino)',
#     'timezone': 'Europe/Rome',
#     'iata': 'FCO',
#     'icao': 'LIRF',
#     'terminal': '1',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-17T00:15:00+00:00',
#     'delay': None,
#     'estimated': '2026-02-17T00:00:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5106',
#     'iata': 'VY5106',
#     'icao': 'VLG5106',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '657',
#      'flight_iata': 'ib657',
#      'flight_icao': 'ibe657'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '34134E'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Charles De Gaulle',
#     'timezone': 'Europe/Paris',
#     'iata': 'CDG',
#     'icao': 'LFPG',
#     'terminal': '3',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2026-02-16T18:45:00+00:00',
#     'estimated': '2026-02-16T18:45:00+00:00',
#     'actual': '2026-02-16T19:13:00+00:00',
#     'estimated_runway': '2026-02-16T19:13:00+00:00',
#     'actual_runway': '2026-02-16T19:13:00+00:00'},
#    'arrival': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T20:55:00+00:00',
#     'delay': 29,
#     'estimated': '2026-02-16T20:48:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5328',
#     'iata': 'VY5328',
#     'icao': 'VLG5328',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '590',
#      'flight_iata': 'ib590',
#      'flight_icao': 'ibe590'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '34134D'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Heathrow',
#     'timezone': 'Europe/London',
#     'iata': 'LHR',
#     'icao': 'EGLL',
#     'terminal': '5',
#     'gate': 'A21',
#     'delay': None,
#     'scheduled': '2026-02-16T16:30:00+00:00',
#     'estimated': '2026-02-16T16:30:00+00:00',
#     'actual': '2026-02-16T17:11:00+00:00',
#     'estimated_runway': '2026-02-16T17:11:00+00:00',
#     'actual_runway': '2026-02-16T17:11:00+00:00'},
#    'arrival': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4S',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T20:00:00+00:00',
#     'delay': 41,
#     'estimated': '2026-02-16T19:40:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '9544',
#     'iata': 'VY9544',
#     'icao': 'VLG9544',
#     'codeshared': {'airline_name': 'british airways',
#      'airline_iata': 'ba',
#      'airline_icao': 'baw',
# ...
#     'iata': None,
#     'icao': None,
#     'icao24': '347501'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'El Prat De Llobregat',
#     'timezone': 'Europe/Madrid',
#     'iata': 'BCN',
#     'icao': 'LEBL',
#     'terminal': '1',
#     'gate': 'C82',
#     'delay': None,
#     'scheduled': '2026-02-16T18:25:00+00:00',
#     'estimated': '2026-02-16T18:25:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Schiphol',
#     'timezone': 'Europe/Amsterdam',
#     'iata': 'AMS',
#     'icao': 'EHAM',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T20:55:00+00:00',
#     'delay': None,
#     'estimated': None,
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': None, 'iata': 'VY', 'icao': 'VLG', 'codeshared': None},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '346692'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'landed',
#    'departure': {'airport': 'El Prat De Llobregat',
#     'timezone': 'Europe/Madrid',
#     'iata': 'BCN',
#     'icao': 'LEBL',
#     'terminal': '1',
#     'gate': 'D18',
#     'delay': 2,
#     'scheduled': '2026-02-16T17:00:00+00:00',
#     'estimated': '2026-02-16T17:00:00+00:00',
#     'actual': '2026-02-16T17:08:00+00:00',
#     'estimated_runway': '2026-02-16T17:08:00+00:00',
#     'actual_runway': '2026-02-16T17:08:00+00:00'},
#    'arrival': {'airport': 'Heathrow',
#     'timezone': 'Europe/London',
#     'iata': 'LHR',
#     'icao': 'EGLL',
#     'terminal': '5',
#     'gate': None,
#     'baggage': '8',
#     'scheduled': '2026-02-16T18:20:00+00:00',
#     'delay': 2,
#     'estimated': '2026-02-16T18:22:00+00:00',
#     'actual': '2026-02-16T18:22:00+00:00',
#     'estimated_runway': '2026-02-16T18:22:00+00:00',
#     'actual_runway': '2026-02-16T18:22:00+00:00'},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '9563',
#     'iata': 'VY9563',
#     'icao': 'VLG9563',
#     'codeshared': {'airline_name': 'british airways',
#      'airline_iata': 'ba',
#      'airline_icao': 'baw',
#      'flight_number': '485',
#      'flight_iata': 'ba485',
#      'flight_icao': 'baw485'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '407B8F'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4S',
#     'gate': None,
#     'delay': 18,
#     'scheduled': '2026-02-16T15:40:00+00:00',
#     'estimated': '2026-02-16T15:40:00+00:00',
#     'actual': '2026-02-16T16:22:00+00:00',
#     'estimated_runway': '2026-02-16T16:22:00+00:00',
#     'actual_runway': '2026-02-16T16:22:00+00:00'},
#    'arrival': {'airport': 'Lisbon Portela',
#     'timezone': 'Europe/Lisbon',
#     'iata': 'LIS',
#     'icao': 'LPPT',
#     'terminal': '1',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T16:05:00+00:00',
#     'delay': 43,
#     'estimated': '2026-02-16T16:23:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5064',
#     'iata': 'VY5064',
#     'icao': 'VLG5064',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '533',
#      'flight_iata': 'ib533',
#      'flight_icao': 'ibe533'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '345691'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4S',
#     'gate': None,
#     'delay': 2,
#     'scheduled': '2026-02-16T15:05:00+00:00',
#     'estimated': '2026-02-16T15:05:00+00:00',
#     'actual': '2026-02-16T15:25:00+00:00',
#     'estimated_runway': '2026-02-16T15:25:00+00:00',
#     'actual_runway': '2026-02-16T15:25:00+00:00'},
#    'arrival': {'airport': 'Heathrow',
#     'timezone': 'Europe/London',
#     'iata': 'LHR',
#     'icao': 'EGLL',
#     'terminal': '5',
#     'gate': None,
#     'baggage': '10',
#     'scheduled': '2026-02-16T16:35:00+00:00',
#     'delay': 2,
#     'estimated': '2026-02-16T16:34:00+00:00',
#     'actual': '2026-02-16T16:37:00+00:00',
#     'estimated_runway': '2026-02-16T16:37:00+00:00',
#     'actual_runway': '2026-02-16T16:37:00+00:00'},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5226',
#     'iata': 'VY5226',
#     'icao': 'VLG5226',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '719',
#      'flight_iata': 'ib719',
#      'flight_icao': 'ibe719'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '34660B'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Menara',
#     'timezone': 'Africa/Casablanca',
#     'iata': 'RAK',
#     'icao': 'GMMX',
#     'terminal': '1',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2026-02-16T21:35:00+00:00',
#     'estimated': '2026-02-16T21:35:00+00:00',
#     'actual': '2026-02-16T20:58:00+00:00',
#     'estimated_runway': '2026-02-16T20:58:00+00:00',
#     'actual_runway': '2026-02-16T20:58:00+00:00'},
#    'arrival': {'airport': 'El Prat De Llobregat',
#     'timezone': 'Europe/Madrid',
#     'iata': 'BCN',
#     'icao': 'LEBL',
#     'terminal': '1',
#     'gate': None,
#     'baggage': '15',
#     'scheduled': '2026-02-16T23:59:00+00:00',
#     'delay': None,
#     'estimated': '2026-02-16T23:53:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '7333',
#     'iata': 'VY7333',
#     'icao': 'VLG7333',
#     'codeshared': None},
#    'aircraft': {'registration': 'EC-NLX',
#     'iata': 'A321',
#     'icao': 'A321',
#     'icao24': '346691'},
#    'live': {'updated': '2026-02-16T21:44:43+00:00',
#     'latitude': 34.6053,
#     'longitude': -2.5869,
#     'altitude': 10668,
#     'direction': 71.75,
#     'speed_horizontal': 904.824,
#     'speed_vertical': 0,
#     'is_ground': False}},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2026-02-16T20:50:00+00:00',
#     'estimated': '2026-02-16T20:50:00+00:00',
#     'actual': '2026-02-16T21:04:00+00:00',
#     'estimated_runway': '2026-02-16T21:04:00+00:00',
#     'actual_runway': '2026-02-16T21:04:00+00:00'},
#    'arrival': {'airport': 'Linate',
#     'timezone': 'Europe/Rome',
#     'iata': 'LIN',
#     'icao': 'LIML',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T23:00:00+00:00',
#     'delay': 15,
#     'estimated': '2026-02-16T22:45:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5120',
#     'iata': 'VY5120',
#     'icao': 'VLG5120',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '667',
#      'flight_iata': 'ib667',
#      'flight_icao': 'ibe667'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '346147'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4',
#     'gate': None,
#     'delay': 21,
#     'scheduled': '2026-02-16T18:05:00+00:00',
#     'estimated': '2026-02-16T18:05:00+00:00',
#     'actual': '2026-02-16T18:36:00+00:00',
#     'estimated_runway': '2026-02-16T18:36:00+00:00',
#     'actual_runway': '2026-02-16T18:36:00+00:00'},
#    'arrival': {'airport': 'Orly',
#     'timezone': 'Europe/Paris',
#     'iata': 'ORY',
#     'icao': 'LFPO',
#     'terminal': '1',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T20:05:00+00:00',
#     'delay': 21,
#     'estimated': '2026-02-16T20:22:00+00:00',
#     'actual': '2026-02-16T20:26:00+00:00',
#     'estimated_runway': '2026-02-16T20:26:00+00:00',
#     'actual_runway': '2026-02-16T20:26:00+00:00'},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5145',
#     'iata': 'VY5145',
#     'icao': 'VLG5145',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '581',
#      'flight_iata': 'ib581',
#      'flight_icao': 'ibe581'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '34250A'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Milano Malpensa',
#     'timezone': 'Europe/Rome',
#     'iata': 'MXP',
#     'icao': 'LIMC',
#     'terminal': '1',
#     'gate': None,
#     'delay': 1,
#     'scheduled': '2026-02-16T21:55:00+00:00',
#     'estimated': '2026-02-16T21:55:00+00:00',
#     'actual': '2026-02-16T22:21:00+00:00',
#     'estimated_runway': '2026-02-16T22:21:00+00:00',
#     'actual_runway': '2026-02-16T22:21:00+00:00'},
#    'arrival': {'airport': 'El Prat De Llobregat',
#     'timezone': 'Europe/Madrid',
#     'iata': 'BCN',
#     'icao': 'LEBL',
#     'terminal': '1',
#     'gate': None,
#     'baggage': '9',
#     'scheduled': '2026-02-16T23:35:00+00:00',
#     'delay': 26,
#     'estimated': '2026-02-16T23:36:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '6337',
#     'iata': 'VY6337',
#     'icao': 'VLG6337',
#     'codeshared': None},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '344156'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Brussels Airport',
#     'timezone': 'Europe/Brussels',
#     'iata': 'BRU',
#     'icao': 'EBBR',
#     'terminal': None,
#     'gate': None,
#     'delay': 10,
#     'scheduled': '2026-02-16T19:45:00+00:00',
#     'estimated': '2026-02-16T19:45:00+00:00',
#     'actual': '2026-02-16T20:25:00+00:00',
#     'estimated_runway': '2026-02-16T20:25:00+00:00',
#     'actual_runway': '2026-02-16T20:25:00+00:00'},
#    'arrival': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T22:10:00+00:00',
#     'delay': 40,
#     'estimated': '2026-02-16T22:20:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5093',
#     'iata': 'VY5093',
#     'icao': 'VLG5093',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '602',
#      'flight_iata': 'ib602',
#      'flight_icao': 'ibe602'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '3423C4'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Prague Vaclav Havel Airport',
#     'timezone': 'Europe/Prague',
#     'iata': 'PRG',
#     'icao': 'LKPR',
#     'terminal': '2',
#     'gate': 'D1',
#     'delay': None,
#     'scheduled': '2026-02-16T21:10:00+00:00',
#     'estimated': '2026-02-16T21:10:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'El Prat De Llobregat',
#     'timezone': 'Europe/Madrid',
#     'iata': 'BCN',
#     'icao': 'LEBL',
#     'terminal': '1',
#     'gate': None,
#     'baggage': '13',
#     'scheduled': '2026-02-16T23:40:00+00:00',
#     'delay': 59,
#     'estimated': None,
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '8655',
#     'iata': 'VY8655',
#     'icao': 'VLG8655',
#     'codeshared': None},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '345101'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Mahon',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAH',
#     'icao': 'LEMH',
#     'terminal': None,
#     'gate': '2',
#     'delay': None,
#     'scheduled': '2026-02-16T21:30:00+00:00',
#     'estimated': '2026-02-16T21:30:00+00:00',
#     'actual': '2026-02-16T21:27:00+00:00',
#     'estimated_runway': '2026-02-16T21:27:00+00:00',
#     'actual_runway': '2026-02-16T21:27:00+00:00'},
#    'arrival': {'airport': 'El Prat De Llobregat',
#     'timezone': 'Europe/Madrid',
#     'iata': 'BCN',
#     'icao': 'LEBL',
#     'terminal': '1',
#     'gate': None,
#     'baggage': '2',
#     'scheduled': '2026-02-16T22:20:00+00:00',
#     'delay': None,
#     'estimated': '2026-02-16T22:00:00+00:00',
#     'actual': '2026-02-16T22:02:00+00:00',
#     'estimated_runway': '2026-02-16T22:02:00+00:00',
#     'actual_runway': '2026-02-16T22:02:00+00:00'},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '3725',
#     'iata': 'VY3725',
#     'icao': 'VLG3725',
#     'codeshared': None},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '345204'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'El Prat De Llobregat',
#     'timezone': 'Europe/Madrid',
#     'iata': 'BCN',
#     'icao': 'LEBL',
#     'terminal': '1',
#     'gate': 'D18',
#     'delay': None,
#     'scheduled': '2026-02-16T22:00:00+00:00',
#     'estimated': '2026-02-16T22:00:00+00:00',
#     'actual': '2026-02-16T22:16:00+00:00',
#     'estimated_runway': '2026-02-16T22:16:00+00:00',
#     'actual_runway': '2026-02-16T22:16:00+00:00'},
#    'arrival': {'airport': 'Gatwick',
#     'timezone': 'Europe/London',
#     'iata': 'LGW',
#     'icao': 'EGKK',
#     'terminal': 'S',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T23:20:00+00:00',
#     'delay': None,
#     'estimated': '2026-02-16T23:08:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '7842',
#     'iata': 'VY7842',
#     'icao': 'VLG7842',
#     'codeshared': None},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '3451D3'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'landed',
#    'departure': {'airport': 'El Prat De Llobregat',
#     'timezone': 'Europe/Madrid',
#     'iata': 'BCN',
#     'icao': 'LEBL',
#     'terminal': '1',
#     'gate': 'B31',
#     'delay': None,
#     'scheduled': '2026-02-16T22:00:00+00:00',
#     'estimated': '2026-02-16T22:00:00+00:00',
#     'actual': '2026-02-16T21:59:00+00:00',
#     'estimated_runway': '2026-02-16T21:59:00+00:00',
#     'actual_runway': '2026-02-16T21:59:00+00:00'},
#    'arrival': {'airport': 'Ibiza',
#     'timezone': 'Europe/Madrid',
#     'iata': 'IBZ',
#     'icao': 'LEIB',
#     'terminal': None,
#     'gate': None,
#     'baggage': '8',
#     'scheduled': '2026-02-16T22:55:00+00:00',
#     'delay': None,
#     'estimated': None,
#     'actual': '2026-02-16T22:30:00+00:00',
#     'estimated_runway': '2026-02-16T22:30:00+00:00',
#     'actual_runway': '2026-02-16T22:30:00+00:00'},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '3512',
#     'iata': 'VY3512',
#     'icao': 'VLG3512',
#     'codeshared': None},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '348208'},
#    'live': None}]}

# %% [markdown]
# - #### Imprime de forma clara algunos de los campos de la respuesta JSON.

# %%
r_vuelos.json()
# Out:
# {'pagination': {'limit': 100, 'offset': 0, 'count': 100, 'total': 2064},
#  'data': [{'flight_date': '2026-02-17',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Ben Gurion International',
#     'timezone': 'Asia/Jerusalem',
#     'iata': 'TLV',
#     'icao': 'LLBG',
#     'terminal': '3',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2026-02-17T06:00:00+00:00',
#     'estimated': '2026-02-17T06:00:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4S',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-17T10:30:00+00:00',
#     'delay': 15,
#     'estimated': None,
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5284',
#     'iata': 'VY5284',
#     'icao': 'VLG5284',
#     'codeshared': {'airline_name': 'iberia express',
#      'airline_iata': 'i2',
#      'airline_icao': 'ibs',
#      'flight_number': '1874',
#      'flight_iata': 'i21874',
#      'flight_icao': 'ibs1874'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '347247'},
#    'live': None},
#   {'flight_date': '2026-02-17',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'El Prat De Llobregat',
#     'timezone': 'Europe/Madrid',
#     'iata': 'BCN',
#     'icao': 'LEBL',
#     'terminal': '1',
#     'gate': 'D',
#     'delay': None,
#     'scheduled': '2026-02-17T01:30:00+00:00',
#     'estimated': '2026-02-17T01:30:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Ezeiza Ministro Pistarini',
#     'timezone': 'America/Argentina/Buenos_Aires',
#     'iata': 'EZE',
#     'icao': 'SAEZ',
#     'terminal': 'IA',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-17T11:10:00+00:00',
#     'delay': None,
#     'estimated': None,
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '9781',
#     'iata': 'VY9781',
#     'icao': 'VLG9781',
#     'codeshared': {'airline_name': 'level',
#      'airline_iata': 'll',
#      'airline_icao': 'lvl',
#      'flight_number': '2601',
#      'flight_iata': 'll2601',
#      'flight_icao': 'lvl2601'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '346605'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2026-02-16T23:00:00+00:00',
#     'estimated': '2026-02-16T23:00:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Lisbon Portela',
#     'timezone': 'Europe/Lisbon',
#     'iata': 'LIS',
#     'icao': 'LPPT',
#     'terminal': '1',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T23:25:00+00:00',
#     'delay': 18,
#     'estimated': None,
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5219',
#     'iata': 'VY5219',
#     'icao': 'VLG5219',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '539',
#      'flight_iata': 'ib539',
#      'flight_icao': 'ibe539'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '3423C4'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Blaise Diagne International Airport\r\n',
#     'timezone': None,
#     'iata': 'DSS',
#     'icao': 'GOBD',
#     'terminal': None,
#     'gate': None,
#     'delay': 1,
#     'scheduled': '2026-02-16T20:35:00+00:00',
#     'estimated': '2026-02-16T20:35:00+00:00',
#     'actual': '2026-02-16T20:53:00+00:00',
#     'estimated_runway': '2026-02-16T20:53:00+00:00',
#     'actual_runway': '2026-02-16T20:53:00+00:00'},
#    'arrival': {'airport': 'El Prat De Llobregat',
#     'timezone': 'Europe/Madrid',
#     'iata': 'BCN',
#     'icao': 'LEBL',
#     'terminal': 'T1',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-17T02:15:00+00:00',
#     'delay': 18,
#     'estimated': '2026-02-17T02:16:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '7887',
#     'iata': 'VY7887',
#     'icao': 'VLG7887',
#     'codeshared': None},
#    'aircraft': {'registration': 'EC-MFN',
#     'iata': 'A320',
#     'icao': 'A320',
#     'icao24': '344697'},
#    'live': {'updated': '2026-02-16T21:41:44+00:00',
#     'latitude': 19.7422,
#     'longitude': -13.979,
#     'altitude': 10668,
#     'direction': 28,
#     'speed_horizontal': 900.072,
#     'speed_vertical': 0,
#     'is_ground': False}},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2026-02-16T21:40:00+00:00',
#     'estimated': '2026-02-16T21:40:00+00:00',
#     'actual': '2026-02-16T22:13:00+00:00',
#     'estimated_runway': '2026-02-16T22:13:00+00:00',
#     'actual_runway': '2026-02-16T22:13:00+00:00'},
#    'arrival': {'airport': 'Charles De Gaulle',
#     'timezone': 'Europe/Paris',
#     'iata': 'CDG',
#     'icao': 'LFPG',
#     'terminal': '3',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T23:50:00+00:00',
#     'delay': None,
#     'estimated': '2026-02-16T23:45:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5250',
#     'iata': 'VY5250',
#     'icao': 'VLG5250',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '591',
#      'flight_iata': 'ib591',
#      'flight_icao': 'ibe591'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '34134D'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4S',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2026-02-16T20:50:00+00:00',
#     'estimated': '2026-02-16T20:50:00+00:00',
#     'actual': '2026-02-16T21:07:00+00:00',
#     'estimated_runway': '2026-02-16T21:07:00+00:00',
#     'actual_runway': '2026-02-16T21:07:00+00:00'},
#    'arrival': {'airport': 'Heathrow',
#     'timezone': 'Europe/London',
#     'iata': 'LHR',
#     'icao': 'EGLL',
#     'terminal': '5',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T22:10:00+00:00',
#     'delay': 18,
#     'estimated': '2026-02-16T21:58:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '9547',
#     'iata': 'VY9547',
#     'icao': 'VLG9547',
#     'codeshared': {'airline_name': 'british airways',
#      'airline_iata': 'ba',
#      'airline_icao': 'baw',
#      'flight_number': '469',
#      'flight_iata': 'ba469',
#      'flight_icao': 'baw469'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '4009C5'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Blagnac',
#     'timezone': 'Europe/Paris',
#     'iata': 'TLS',
#     'icao': 'LFBO',
#     'terminal': None,
#     'gate': None,
#     'delay': 2,
#     'scheduled': '2026-02-16T20:40:00+00:00',
#     'estimated': '2026-02-16T20:40:00+00:00',
#     'actual': '2026-02-16T21:07:00+00:00',
#     'estimated_runway': '2026-02-16T21:07:00+00:00',
#     'actual_runway': '2026-02-16T21:07:00+00:00'},
#    'arrival': {'airport': 'El Prat De Llobregat',
#     'timezone': 'Europe/Madrid',
#     'iata': 'BCN',
#     'icao': 'LEBL',
#     'terminal': 'T1',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T21:35:00+00:00',
#     'delay': 27,
#     'estimated': '2026-02-16T21:37:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '4084',
#     'iata': 'VY4084',
#     'icao': 'VLG4084',
#     'codeshared': None},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '3424D2'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'St-Exupéry',
#     'timezone': 'Europe/Paris',
#     'iata': 'LYS',
#     'icao': 'LFLL',
#     'terminal': None,
#     'gate': None,
#     'delay': None,
#     'scheduled': '2026-02-16T20:35:00+00:00',
#     'estimated': '2026-02-16T20:35:00+00:00',
#     'actual': '2026-02-16T21:03:00+00:00',
#     'estimated_runway': '2026-02-16T21:03:00+00:00',
#     'actual_runway': '2026-02-16T21:03:00+00:00'},
#    'arrival': {'airport': 'El Prat De Llobregat',
#     'timezone': 'Europe/Madrid',
#     'iata': 'BCN',
#     'icao': 'LEBL',
#     'terminal': 'T1',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T21:55:00+00:00',
#     'delay': 28,
#     'estimated': '2026-02-16T21:54:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '4389',
#     'iata': 'VY4389',
#     'icao': 'VLG4389',
#     'codeshared': None},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '344099'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Heathrow',
#     'timezone': 'Europe/London',
#     'iata': 'LHR',
#     'icao': 'EGLL',
#     'terminal': '5',
#     'gate': 'A8',
#     'delay': 14,
#     'scheduled': '2026-02-16T19:40:00+00:00',
#     'estimated': '2026-02-16T19:40:00+00:00',
#     'actual': '2026-02-16T20:24:00+00:00',
#     'estimated_runway': '2026-02-16T20:24:00+00:00',
#     'actual_runway': '2026-02-16T20:24:00+00:00'},
#    'arrival': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4S',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T23:05:00+00:00',
#     'delay': 44,
#     'estimated': '2026-02-16T23:19:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5186',
#     'iata': 'VY5186',
#     'icao': 'VLG5186',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '726',
#      'flight_iata': 'ib726',
#      'flight_icao': 'ibe726'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '3472CC'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Marseille Provence Airport',
#     'timezone': 'Europe/Paris',
#     'iata': 'MRS',
#     'icao': 'LFML',
#     'terminal': None,
#     'gate': None,
#     'delay': None,
#     'scheduled': '2026-02-16T21:10:00+00:00',
#     'estimated': '2026-02-16T21:10:00+00:00',
#     'actual': '2026-02-16T21:11:00+00:00',
#     'estimated_runway': '2026-02-16T21:11:00+00:00',
#     'actual_runway': '2026-02-16T21:11:00+00:00'},
#    'arrival': {'airport': 'El Prat De Llobregat',
#     'timezone': 'Europe/Madrid',
#     'iata': 'BCN',
#     'icao': 'LEBL',
#     'terminal': 'T1',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T22:15:00+00:00',
#     'delay': 1,
#     'estimated': '2026-02-16T21:50:00+00:00',
#     'actual': '2026-02-16T21:55:00+00:00',
#     'estimated_runway': '2026-02-16T21:55:00+00:00',
#     'actual_runway': '2026-02-16T21:55:00+00:00'},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '4154',
#     'iata': 'VY4154',
#     'icao': 'VLG4154',
#     'codeshared': None},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '3444D1'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2026-02-16T20:40:00+00:00',
#     'estimated': '2026-02-16T20:40:00+00:00',
#     'actual': '2026-02-16T21:01:00+00:00',
#     'estimated_runway': '2026-02-16T21:01:00+00:00',
#     'actual_runway': '2026-02-16T21:01:00+00:00'},
#    'arrival': {'airport': 'Agoncillo',
#     'timezone': 'Europe/Madrid',
#     'iata': 'RJL',
#     'icao': 'LERJ',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T21:55:00+00:00',
#     'delay': 22,
#     'estimated': '2026-02-16T21:48:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5622',
#     'iata': 'VY5622',
#     'icao': 'VLG5622',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '2222',
#      'flight_iata': 'ib2222',
#      'flight_icao': 'ibe2222'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '344307'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4',
#     'gate': None,
#     'delay': 4,
#     'scheduled': '2026-02-16T21:35:00+00:00',
#     'estimated': '2026-02-16T21:35:00+00:00',
#     'actual': '2026-02-16T22:11:00+00:00',
#     'estimated_runway': '2026-02-16T22:11:00+00:00',
#     'actual_runway': '2026-02-16T22:11:00+00:00'},
#    'arrival': {'airport': 'El Prat De Llobregat',
#     'timezone': 'Europe/Madrid',
#     'iata': 'BCN',
#     'icao': 'LEBL',
#     'terminal': '1',
#     'gate': None,
#     'baggage': '15',
#     'scheduled': '2026-02-16T22:50:00+00:00',
#     'delay': 37,
#     'estimated': '2026-02-16T22:54:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5091',
#     'iata': 'VY5091',
#     'icao': 'VLG5091',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '427',
#      'flight_iata': 'ib427',
#      'flight_icao': 'ibe427'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '347344'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Heathrow',
#     'timezone': 'Europe/London',
#     'iata': 'LHR',
#     'icao': 'EGLL',
#     'terminal': '5',
#     'gate': 'A21',
#     'delay': None,
#     'scheduled': '2026-02-16T19:15:00+00:00',
#     'estimated': '2026-02-16T19:15:00+00:00',
#     'actual': '2026-02-16T19:48:00+00:00',
#     'estimated_runway': '2026-02-16T19:48:00+00:00',
#     'actual_runway': '2026-02-16T19:48:00+00:00'},
#    'arrival': {'airport': 'El Prat De Llobregat',
#     'timezone': 'Europe/Madrid',
#     'iata': 'BCN',
#     'icao': 'LEBL',
#     'terminal': '1',
#     'gate': None,
#     'baggage': '13',
#     'scheduled': '2026-02-16T22:30:00+00:00',
#     'delay': 33,
#     'estimated': '2026-02-16T22:22:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '9570',
#     'iata': 'VY9570',
#     'icao': 'VLG9570',
#     'codeshared': {'airline_name': 'british airways',
#      'airline_iata': 'ba',
#      'airline_icao': 'baw',
#      'flight_number': '492',
#      'flight_iata': 'ba492',
#      'flight_icao': 'baw492'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '407B8F'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2026-02-16T19:50:00+00:00',
#     'estimated': '2026-02-16T19:50:00+00:00',
#     'actual': '2026-02-16T20:31:00+00:00',
#     'estimated_runway': '2026-02-16T20:31:00+00:00',
#     'actual_runway': '2026-02-16T20:31:00+00:00'},
#    'arrival': {'airport': 'Frankfurt International Airport',
#     'timezone': 'Europe/Berlin',
#     'iata': 'FRA',
#     'icao': 'EDDF',
#     'terminal': '2',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T22:35:00+00:00',
#     'delay': 42,
#     'estimated': '2026-02-16T22:32:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5520',
#     'iata': 'VY5520',
#     'icao': 'VLG5520',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '1331',
#      'flight_iata': 'ib1331',
#      'flight_icao': 'ibe1331'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '345250'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Heathrow',
#     'timezone': 'Europe/London',
#     'iata': 'LHR',
#     'icao': 'EGLL',
#     'terminal': '5',
#     'gate': 'A8',
#     'delay': None,
#     'scheduled': '2026-02-16T19:05:00+00:00',
#     'estimated': '2026-02-16T19:05:00+00:00',
#     'actual': '2026-02-16T19:43:00+00:00',
#     'estimated_runway': '2026-02-16T19:43:00+00:00',
#     'actual_runway': '2026-02-16T19:43:00+00:00'},
#    'arrival': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4S',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T22:30:00+00:00',
#     'delay': 38,
#     'estimated': None,
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5187',
#     'iata': 'VY5187',
#     'icao': 'VLG5187',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '724',
#      'flight_iata': 'ib724',
#      'flight_icao': 'ibe724'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '345692'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Heathrow',
#     'timezone': 'Europe/London',
#     'iata': 'LHR',
#     'icao': 'EGLL',
#     'terminal': '5',
#     'gate': 'C56',
#     'delay': None,
#     'scheduled': '2026-02-16T18:45:00+00:00',
#     'estimated': '2026-02-16T18:45:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4S',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T22:10:00+00:00',
#     'delay': 37,
#     'estimated': None,
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5227',
#     'iata': 'VY5227',
#     'icao': 'VLG5227',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '722',
#      'flight_iata': 'ib722',
#      'flight_icao': 'ibe722'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '3444C4'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2026-02-16T20:00:00+00:00',
#     'estimated': '2026-02-16T20:00:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'El Prat De Llobregat',
#     'timezone': 'Europe/Madrid',
#     'iata': 'BCN',
#     'icao': 'LEBL',
#     'terminal': '1',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T21:20:00+00:00',
#     'delay': 96,
#     'estimated': None,
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5079',
#     'iata': 'VY5079',
#     'icao': 'VLG5079',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '425',
#      'flight_iata': 'ib425',
#      'flight_icao': 'ibe425'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '347288'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'El Prat De Llobregat',
#     'timezone': 'Europe/Madrid',
#     'iata': 'BCN',
#     'icao': 'LEBL',
#     'terminal': '1',
#     'gate': 'D',
#     'delay': None,
#     'scheduled': '2026-02-16T23:35:00+00:00',
#     'estimated': '2026-02-16T23:35:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Arturo Merino Benitez',
#     'timezone': 'America/Santiago',
#     'iata': 'SCL',
#     'icao': 'SCEL',
#     'terminal': '2',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-17T10:10:00+00:00',
#     'delay': 13,
#     'estimated': None,
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '9785',
#     'iata': 'VY9785',
#     'icao': 'VLG9785',
#     'codeshared': {'airline_name': 'level',
#      'airline_iata': 'll',
#      'airline_icao': 'lvl',
#      'flight_number': '2605',
#      'flight_iata': 'll2605',
#      'flight_icao': 'lvl2605'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '34718D'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'El Prat De Llobregat',
#     'timezone': 'Europe/Madrid',
#     'iata': 'BCN',
#     'icao': 'LEBL',
#     'terminal': '1',
#     'gate': 'A06',
#     'delay': None,
#     'scheduled': '2026-02-16T21:15:00+00:00',
#     'estimated': '2026-02-16T21:15:00+00:00',
#     'actual': '2026-02-16T21:32:00+00:00',
#     'estimated_runway': '2026-02-16T21:32:00+00:00',
#     'actual_runway': '2026-02-16T21:32:00+00:00'},
#    'arrival': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4S',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T22:40:00+00:00',
#     'delay': 18,
#     'estimated': '2026-02-16T22:28:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5100',
#     'iata': 'VY5100',
#     'icao': 'VLG5100',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '424',
#      'flight_iata': 'ib424',
#      'flight_icao': 'ibe424'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '34224E'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4',
#     'gate': None,
#     'delay': 1,
#     'scheduled': '2026-02-16T19:40:00+00:00',
#     'estimated': '2026-02-16T19:40:00+00:00',
#     'actual': '2026-02-16T20:08:00+00:00',
#     'estimated_runway': '2026-02-16T20:08:00+00:00',
#     'actual_runway': '2026-02-16T20:08:00+00:00'},
#    'arrival': {'airport': 'Schiphol',
#     'timezone': 'Europe/Amsterdam',
#     'iata': 'AMS',
#     'icao': 'EHAM',
#     'terminal': '1',
#     'gate': 'C10',
#     'baggage': '4',
#     'scheduled': '2026-02-16T22:20:00+00:00',
#     'delay': 1,
#     'estimated': '2026-02-16T22:22:00+00:00',
#     'actual': '2026-02-16T22:21:00+00:00',
#     'estimated_runway': '2026-02-16T22:21:00+00:00',
#     'actual_runway': '2026-02-16T22:21:00+00:00'},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5162',
#     'iata': 'VY5162',
#     'icao': 'VLG5162',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '739',
#      'flight_iata': 'ib739',
#      'flight_icao': 'ibe739'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '346316'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'El Prat De Llobregat',
#     'timezone': 'Europe/Madrid',
#     'iata': 'BCN',
#     'icao': 'LEBL',
#     'terminal': '1',
#     'gate': 'D14',
#     'delay': None,
#     'scheduled': '2026-02-16T21:00:00+00:00',
#     'estimated': '2026-02-16T21:00:00+00:00',
#     'actual': '2026-02-16T21:21:00+00:00',
#     'estimated_runway': '2026-02-16T21:21:00+00:00',
#     'actual_runway': '2026-02-16T21:21:00+00:00'},
#    'arrival': {'airport': 'Heathrow',
#     'timezone': 'Europe/London',
#     'iata': 'LHR',
#     'icao': 'EGLL',
#     'terminal': '5',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T22:20:00+00:00',
#     'delay': 22,
#     'estimated': '2026-02-16T22:11:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '9569',
#     'iata': 'VY9569',
#     'icao': 'VLG9569',
#     'codeshared': {'airline_name': 'british airways',
#      'airline_iata': 'ba',
#      'airline_icao': 'baw',
#      'flight_number': '491',
#      'flight_iata': 'ba491',
#      'flight_icao': 'baw491'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '407462'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4S',
#     'gate': None,
#     'delay': 5,
#     'scheduled': '2026-02-16T19:25:00+00:00',
#     'estimated': '2026-02-16T19:25:00+00:00',
#     'actual': '2026-02-16T19:45:00+00:00',
#     'estimated_runway': '2026-02-16T19:45:00+00:00',
#     'actual_runway': '2026-02-16T19:45:00+00:00'},
#    'arrival': {'airport': 'Heathrow',
#     'timezone': 'Europe/London',
#     'iata': 'LHR',
#     'icao': 'EGLL',
#     'terminal': '5',
#     'gate': None,
#     'baggage': '10',
#     'scheduled': '2026-02-16T20:45:00+00:00',
#     'delay': 5,
#     'estimated': '2026-02-16T20:50:00+00:00',
#     'actual': '2026-02-16T20:50:00+00:00',
#     'estimated_runway': '2026-02-16T20:50:00+00:00',
#     'actual_runway': '2026-02-16T20:50:00+00:00'},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '9543',
#     'iata': 'VY9543',
#     'icao': 'VLG9543',
#     'codeshared': {'airline_name': 'british airways',
#      'airline_iata': 'ba',
#      'airline_icao': 'baw',
#      'flight_number': '467',
#      'flight_iata': 'ba467',
#      'flight_icao': 'baw467'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '406BBB'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'landed',
#    'departure': {'airport': 'El Prat De Llobregat',
#     'timezone': 'Europe/Madrid',
#     'iata': 'BCN',
#     'icao': 'LEBL',
#     'terminal': '1',
#     'gate': 'D08',
#     'delay': 12,
#     'scheduled': '2026-02-16T20:00:00+00:00',
#     'estimated': '2026-02-16T20:00:00+00:00',
#     'actual': '2026-02-16T20:14:00+00:00',
#     'estimated_runway': '2026-02-16T20:14:00+00:00',
#     'actual_runway': '2026-02-16T20:14:00+00:00'},
#    'arrival': {'airport': 'Heathrow',
#     'timezone': 'Europe/London',
#     'iata': 'LHR',
#     'icao': 'EGLL',
#     'terminal': '5',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T21:20:00+00:00',
#     'delay': 12,
#     'estimated': '2026-02-16T21:27:00+00:00',
#     'actual': '2026-02-16T21:32:00+00:00',
#     'estimated_runway': '2026-02-16T21:32:00+00:00',
#     'actual_runway': '2026-02-16T21:32:00+00:00'},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '9565',
#     'iata': 'VY9565',
#     'icao': 'VLG9565',
#     'codeshared': {'airline_name': 'british airways',
#      'airline_iata': 'ba',
#      'airline_icao': 'baw',
#      'flight_number': '487',
#      'flight_iata': 'ba487',
#      'flight_icao': 'baw487'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '400A7D'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2026-02-16T19:40:00+00:00',
#     'estimated': '2026-02-16T19:40:00+00:00',
#     'actual': '2026-02-16T19:52:00+00:00',
#     'estimated_runway': '2026-02-16T19:52:00+00:00',
#     'actual_runway': '2026-02-16T19:52:00+00:00'},
#    'arrival': {'airport': 'Lisbon Portela',
#     'timezone': 'Europe/Lisbon',
#     'iata': 'LIS',
#     'icao': 'LPPT',
#     'terminal': '1',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T20:05:00+00:00',
#     'delay': 12,
#     'estimated': '2026-02-16T19:54:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5748',
#     'iata': 'VY5748',
#     'icao': 'VLG5748',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '1145',
#      'flight_iata': 'ib1145',
#      'flight_icao': 'ibe1145'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '3451D9'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Lisbon Portela',
#     'timezone': 'Europe/Lisbon',
#     'iata': 'LIS',
#     'icao': 'LPPT',
#     'terminal': '1',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2026-02-16T20:45:00+00:00',
#     'estimated': '2026-02-16T20:45:00+00:00',
#     'actual': '2026-02-16T21:14:00+00:00',
#     'estimated_runway': '2026-02-16T21:14:00+00:00',
#     'actual_runway': '2026-02-16T21:14:00+00:00'},
#    'arrival': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4S',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T23:10:00+00:00',
#     'delay': 30,
#     'estimated': '2026-02-16T23:06:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5749',
#     'iata': 'VY5749',
#     'icao': 'VLG5749',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '1146',
#      'flight_iata': 'ib1146',
#      'flight_icao': 'ibe1146'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '3451D9'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2026-02-16T19:10:00+00:00',
#     'estimated': '2026-02-16T19:10:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'El Prat De Llobregat',
#     'timezone': 'Europe/Madrid',
#     'iata': 'BCN',
#     'icao': 'LEBL',
#     'terminal': '1',
#     'gate': None,
#     'baggage': '15',
#     'scheduled': '2026-02-16T20:25:00+00:00',
#     'delay': 56,
#     'estimated': None,
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5063',
#     'iata': 'VY5063',
#     'icao': 'VLG5063',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '423',
#      'flight_iata': 'ib423',
#      'flight_icao': 'ibe423'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '344481'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2026-02-16T22:45:00+00:00',
#     'estimated': '2026-02-16T22:45:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Sur Reina Sofia',
#     'timezone': 'Atlantic/Canary',
#     'iata': 'TFS',
#     'icao': 'GCTS',
#     'terminal': None,
#     'gate': None,
#     'baggage': 'A4',
#     'scheduled': '2026-02-17T00:45:00+00:00',
#     'delay': None,
#     'estimated': None,
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5472',
#     'iata': 'VY5472',
#     'icao': 'VLG5472',
#     'codeshared': {'airline_name': 'iberia express',
#      'airline_iata': 'i2',
#      'airline_icao': 'ibs',
#      'flight_number': '1553',
#      'flight_iata': 'i21553',
#      'flight_icao': 'ibs1553'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '343385'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2026-02-16T22:30:00+00:00',
#     'estimated': '2026-02-16T22:30:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Gran Canaria',
#     'timezone': 'Atlantic/Canary',
#     'iata': 'LPA',
#     'icao': 'GCLP',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-17T00:25:00+00:00',
#     'delay': 13,
#     'estimated': None,
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5411',
#     'iata': 'VY5411',
#     'icao': 'VLG5411',
#     'codeshared': {'airline_name': 'iberia express',
#      'airline_iata': 'i2',
#      'airline_icao': 'ibs',
#      'flight_number': '1631',
#      'flight_iata': 'i21631',
#      'flight_icao': 'ibs1631'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '342188'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Heathrow',
#     'timezone': 'Europe/London',
#     'iata': 'LHR',
#     'icao': 'EGLL',
#     'terminal': '5',
#     'gate': 'A17',
#     'delay': None,
#     'scheduled': '2026-02-16T17:25:00+00:00',
#     'estimated': '2026-02-16T17:25:00+00:00',
#     'actual': '2026-02-16T17:58:00+00:00',
#     'estimated_runway': '2026-02-16T17:58:00+00:00',
#     'actual_runway': '2026-02-16T17:58:00+00:00'},
#    'arrival': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4S',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T20:50:00+00:00',
#     'delay': 33,
#     'estimated': '2026-02-16T20:48:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5181',
#     'iata': 'VY5181',
#     'icao': 'VLG5181',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '720',
#      'flight_iata': 'ib720',
#      'flight_icao': 'ibe720'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '34660B'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Leonardo Da Vinci (Fiumicino)',
#     'timezone': 'Europe/Rome',
#     'iata': 'FCO',
#     'icao': 'LIRF',
#     'terminal': '1',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2026-02-16T20:20:00+00:00',
#     'estimated': '2026-02-16T20:20:00+00:00',
#     'actual': '2026-02-16T20:39:00+00:00',
#     'estimated_runway': '2026-02-16T20:39:00+00:00',
#     'actual_runway': '2026-02-16T20:39:00+00:00'},
#    'arrival': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4S',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T22:55:00+00:00',
#     'delay': 19,
#     'estimated': '2026-02-16T22:49:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5237',
#     'iata': 'VY5237',
#     'icao': 'VLG5237',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '656',
#      'flight_iata': 'ib656',
#      'flight_icao': 'ibe656'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '342091'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Leonardo Da Vinci (Fiumicino)',
#     'timezone': 'Europe/Rome',
#     'iata': 'FCO',
#     'icao': 'LIRF',
#     'terminal': '1',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2026-02-16T19:00:00+00:00',
#     'estimated': '2026-02-16T19:00:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T21:35:00+00:00',
#     'delay': 48,
#     'estimated': None,
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5105',
#     'iata': 'VY5105',
#     'icao': 'VLG5105',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '654',
#      'flight_iata': 'ib654',
#      'flight_icao': 'ibe654'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '346499'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'landed',
#    'departure': {'airport': 'El Prat De Llobregat',
#     'timezone': 'Europe/Madrid',
#     'iata': 'BCN',
#     'icao': 'LEBL',
#     'terminal': '1',
#     'gate': 'A02',
#     'delay': 13,
#     'scheduled': '2026-02-16T18:55:00+00:00',
#     'estimated': '2026-02-16T18:55:00+00:00',
#     'actual': '2026-02-16T19:41:00+00:00',
#     'estimated_runway': '2026-02-16T19:41:00+00:00',
#     'actual_runway': '2026-02-16T19:41:00+00:00'},
#    'arrival': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T20:20:00+00:00',
#     'delay': 13,
#     'estimated': '2026-02-16T20:31:00+00:00',
#     'actual': '2026-02-16T20:33:00+00:00',
#     'estimated_runway': '2026-02-16T20:33:00+00:00',
#     'actual_runway': '2026-02-16T20:33:00+00:00'},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5090',
#     'iata': 'VY5090',
#     'icao': 'VLG5090',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '420',
#      'flight_iata': 'ib420',
#      'flight_icao': 'ibe420'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '347288'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Frankfurt International Airport',
#     'timezone': 'Europe/Berlin',
#     'iata': 'FRA',
#     'icao': 'EDDF',
#     'terminal': '2',
#     'gate': 'D21',
#     'delay': None,
#     'scheduled': '2026-02-16T19:35:00+00:00',
#     'estimated': '2026-02-16T19:35:00+00:00',
#     'actual': '2026-02-16T20:06:00+00:00',
#     'estimated_runway': '2026-02-16T20:06:00+00:00',
#     'actual_runway': '2026-02-16T20:06:00+00:00'},
#    'arrival': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T22:25:00+00:00',
#     'delay': 32,
#     'estimated': '2026-02-16T22:17:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5244',
#     'iata': 'VY5244',
#     'icao': 'VLG5244',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '766',
#      'flight_iata': 'ib766',
#      'flight_icao': 'ibe766'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '34260E'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Lisbon Portela',
#     'timezone': 'Europe/Lisbon',
#     'iata': 'LIS',
#     'icao': 'LPPT',
#     'terminal': '1',
#     'gate': None,
#     'delay': 13,
#     'scheduled': '2026-02-16T18:45:00+00:00',
#     'estimated': '2026-02-16T18:45:00+00:00',
#     'actual': '2026-02-16T19:34:00+00:00',
#     'estimated_runway': '2026-02-16T19:34:00+00:00',
#     'actual_runway': '2026-02-16T19:34:00+00:00'},
#    'arrival': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T21:10:00+00:00',
#     'delay': 13,
#     'estimated': '2026-02-16T21:18:00+00:00',
#     'actual': '2026-02-16T21:23:00+00:00',
#     'estimated_runway': '2026-02-16T21:23:00+00:00',
#     'actual_runway': '2026-02-16T21:23:00+00:00'},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5216',
#     'iata': 'VY5216',
#     'icao': 'VLG5216',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '536',
#      'flight_iata': 'ib536',
#      'flight_icao': 'ibe536'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '3420CC'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Heathrow',
#     'timezone': 'Europe/London',
#     'iata': 'LHR',
#     'icao': 'EGLL',
#     'terminal': '5',
#     'gate': 'A8',
#     'delay': None,
#     'scheduled': '2026-02-16T16:55:00+00:00',
#     'estimated': '2026-02-16T16:55:00+00:00',
#     'actual': '2026-02-16T17:26:00+00:00',
#     'estimated_runway': '2026-02-16T17:26:00+00:00',
#     'actual_runway': '2026-02-16T17:26:00+00:00'},
#    'arrival': {'airport': 'El Prat De Llobregat',
#     'timezone': 'Europe/Madrid',
#     'iata': 'BCN',
#     'icao': 'LEBL',
#     'terminal': '1',
#     'gate': None,
#     'baggage': '14',
#     'scheduled': '2026-02-16T20:05:00+00:00',
#     'delay': 32,
#     'estimated': '2026-02-16T20:01:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '9568',
#     'iata': 'VY9568',
#     'icao': 'VLG9568',
#     'codeshared': {'airline_name': 'british airways',
#      'airline_iata': 'ba',
#      'airline_icao': 'baw',
#      'flight_number': '490',
#      'flight_iata': 'ba490',
#      'flight_icao': 'baw490'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '407462'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2026-02-16T21:50:00+00:00',
#     'estimated': '2026-02-16T21:50:00+00:00',
#     'actual': '2026-02-16T22:14:00+00:00',
#     'estimated_runway': '2026-02-16T22:14:00+00:00',
#     'actual_runway': '2026-02-16T22:14:00+00:00'},
#    'arrival': {'airport': 'Leonardo Da Vinci (Fiumicino)',
#     'timezone': 'Europe/Rome',
#     'iata': 'FCO',
#     'icao': 'LIRF',
#     'terminal': '1',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-17T00:15:00+00:00',
#     'delay': None,
#     'estimated': '2026-02-17T00:00:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5106',
#     'iata': 'VY5106',
#     'icao': 'VLG5106',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '657',
#      'flight_iata': 'ib657',
#      'flight_icao': 'ibe657'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '34134E'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Charles De Gaulle',
#     'timezone': 'Europe/Paris',
#     'iata': 'CDG',
#     'icao': 'LFPG',
#     'terminal': '3',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2026-02-16T18:45:00+00:00',
#     'estimated': '2026-02-16T18:45:00+00:00',
#     'actual': '2026-02-16T19:13:00+00:00',
#     'estimated_runway': '2026-02-16T19:13:00+00:00',
#     'actual_runway': '2026-02-16T19:13:00+00:00'},
#    'arrival': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T20:55:00+00:00',
#     'delay': 29,
#     'estimated': '2026-02-16T20:48:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5328',
#     'iata': 'VY5328',
#     'icao': 'VLG5328',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '590',
#      'flight_iata': 'ib590',
#      'flight_icao': 'ibe590'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '34134D'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Heathrow',
#     'timezone': 'Europe/London',
#     'iata': 'LHR',
#     'icao': 'EGLL',
#     'terminal': '5',
#     'gate': 'A21',
#     'delay': None,
#     'scheduled': '2026-02-16T16:30:00+00:00',
#     'estimated': '2026-02-16T16:30:00+00:00',
#     'actual': '2026-02-16T17:11:00+00:00',
#     'estimated_runway': '2026-02-16T17:11:00+00:00',
#     'actual_runway': '2026-02-16T17:11:00+00:00'},
#    'arrival': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4S',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T20:00:00+00:00',
#     'delay': 41,
#     'estimated': '2026-02-16T19:40:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '9544',
#     'iata': 'VY9544',
#     'icao': 'VLG9544',
#     'codeshared': {'airline_name': 'british airways',
#      'airline_iata': 'ba',
#      'airline_icao': 'baw',
#      'flight_number': '468',
# ...
#     'iata': None,
#     'icao': None,
#     'icao24': '347501'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'El Prat De Llobregat',
#     'timezone': 'Europe/Madrid',
#     'iata': 'BCN',
#     'icao': 'LEBL',
#     'terminal': '1',
#     'gate': 'C82',
#     'delay': None,
#     'scheduled': '2026-02-16T18:25:00+00:00',
#     'estimated': '2026-02-16T18:25:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Schiphol',
#     'timezone': 'Europe/Amsterdam',
#     'iata': 'AMS',
#     'icao': 'EHAM',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T20:55:00+00:00',
#     'delay': None,
#     'estimated': None,
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': None, 'iata': 'VY', 'icao': 'VLG', 'codeshared': None},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '346692'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'landed',
#    'departure': {'airport': 'El Prat De Llobregat',
#     'timezone': 'Europe/Madrid',
#     'iata': 'BCN',
#     'icao': 'LEBL',
#     'terminal': '1',
#     'gate': 'D18',
#     'delay': 2,
#     'scheduled': '2026-02-16T17:00:00+00:00',
#     'estimated': '2026-02-16T17:00:00+00:00',
#     'actual': '2026-02-16T17:08:00+00:00',
#     'estimated_runway': '2026-02-16T17:08:00+00:00',
#     'actual_runway': '2026-02-16T17:08:00+00:00'},
#    'arrival': {'airport': 'Heathrow',
#     'timezone': 'Europe/London',
#     'iata': 'LHR',
#     'icao': 'EGLL',
#     'terminal': '5',
#     'gate': None,
#     'baggage': '8',
#     'scheduled': '2026-02-16T18:20:00+00:00',
#     'delay': 2,
#     'estimated': '2026-02-16T18:22:00+00:00',
#     'actual': '2026-02-16T18:22:00+00:00',
#     'estimated_runway': '2026-02-16T18:22:00+00:00',
#     'actual_runway': '2026-02-16T18:22:00+00:00'},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '9563',
#     'iata': 'VY9563',
#     'icao': 'VLG9563',
#     'codeshared': {'airline_name': 'british airways',
#      'airline_iata': 'ba',
#      'airline_icao': 'baw',
#      'flight_number': '485',
#      'flight_iata': 'ba485',
#      'flight_icao': 'baw485'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '407B8F'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4S',
#     'gate': None,
#     'delay': 18,
#     'scheduled': '2026-02-16T15:40:00+00:00',
#     'estimated': '2026-02-16T15:40:00+00:00',
#     'actual': '2026-02-16T16:22:00+00:00',
#     'estimated_runway': '2026-02-16T16:22:00+00:00',
#     'actual_runway': '2026-02-16T16:22:00+00:00'},
#    'arrival': {'airport': 'Lisbon Portela',
#     'timezone': 'Europe/Lisbon',
#     'iata': 'LIS',
#     'icao': 'LPPT',
#     'terminal': '1',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T16:05:00+00:00',
#     'delay': 43,
#     'estimated': '2026-02-16T16:23:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5064',
#     'iata': 'VY5064',
#     'icao': 'VLG5064',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '533',
#      'flight_iata': 'ib533',
#      'flight_icao': 'ibe533'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '345691'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4S',
#     'gate': None,
#     'delay': 2,
#     'scheduled': '2026-02-16T15:05:00+00:00',
#     'estimated': '2026-02-16T15:05:00+00:00',
#     'actual': '2026-02-16T15:25:00+00:00',
#     'estimated_runway': '2026-02-16T15:25:00+00:00',
#     'actual_runway': '2026-02-16T15:25:00+00:00'},
#    'arrival': {'airport': 'Heathrow',
#     'timezone': 'Europe/London',
#     'iata': 'LHR',
#     'icao': 'EGLL',
#     'terminal': '5',
#     'gate': None,
#     'baggage': '10',
#     'scheduled': '2026-02-16T16:35:00+00:00',
#     'delay': 2,
#     'estimated': '2026-02-16T16:34:00+00:00',
#     'actual': '2026-02-16T16:37:00+00:00',
#     'estimated_runway': '2026-02-16T16:37:00+00:00',
#     'actual_runway': '2026-02-16T16:37:00+00:00'},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5226',
#     'iata': 'VY5226',
#     'icao': 'VLG5226',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '719',
#      'flight_iata': 'ib719',
#      'flight_icao': 'ibe719'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '34660B'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Menara',
#     'timezone': 'Africa/Casablanca',
#     'iata': 'RAK',
#     'icao': 'GMMX',
#     'terminal': '1',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2026-02-16T21:35:00+00:00',
#     'estimated': '2026-02-16T21:35:00+00:00',
#     'actual': '2026-02-16T20:58:00+00:00',
#     'estimated_runway': '2026-02-16T20:58:00+00:00',
#     'actual_runway': '2026-02-16T20:58:00+00:00'},
#    'arrival': {'airport': 'El Prat De Llobregat',
#     'timezone': 'Europe/Madrid',
#     'iata': 'BCN',
#     'icao': 'LEBL',
#     'terminal': '1',
#     'gate': None,
#     'baggage': '15',
#     'scheduled': '2026-02-16T23:59:00+00:00',
#     'delay': None,
#     'estimated': '2026-02-16T23:53:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '7333',
#     'iata': 'VY7333',
#     'icao': 'VLG7333',
#     'codeshared': None},
#    'aircraft': {'registration': 'EC-NLX',
#     'iata': 'A321',
#     'icao': 'A321',
#     'icao24': '346691'},
#    'live': {'updated': '2026-02-16T21:44:43+00:00',
#     'latitude': 34.6053,
#     'longitude': -2.5869,
#     'altitude': 10668,
#     'direction': 71.75,
#     'speed_horizontal': 904.824,
#     'speed_vertical': 0,
#     'is_ground': False}},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2026-02-16T20:50:00+00:00',
#     'estimated': '2026-02-16T20:50:00+00:00',
#     'actual': '2026-02-16T21:04:00+00:00',
#     'estimated_runway': '2026-02-16T21:04:00+00:00',
#     'actual_runway': '2026-02-16T21:04:00+00:00'},
#    'arrival': {'airport': 'Linate',
#     'timezone': 'Europe/Rome',
#     'iata': 'LIN',
#     'icao': 'LIML',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T23:00:00+00:00',
#     'delay': 15,
#     'estimated': '2026-02-16T22:45:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5120',
#     'iata': 'VY5120',
#     'icao': 'VLG5120',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '667',
#      'flight_iata': 'ib667',
#      'flight_icao': 'ibe667'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '346147'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'landed',
#    'departure': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4',
#     'gate': None,
#     'delay': 21,
#     'scheduled': '2026-02-16T18:05:00+00:00',
#     'estimated': '2026-02-16T18:05:00+00:00',
#     'actual': '2026-02-16T18:36:00+00:00',
#     'estimated_runway': '2026-02-16T18:36:00+00:00',
#     'actual_runway': '2026-02-16T18:36:00+00:00'},
#    'arrival': {'airport': 'Orly',
#     'timezone': 'Europe/Paris',
#     'iata': 'ORY',
#     'icao': 'LFPO',
#     'terminal': '1',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T20:05:00+00:00',
#     'delay': 21,
#     'estimated': '2026-02-16T20:22:00+00:00',
#     'actual': '2026-02-16T20:26:00+00:00',
#     'estimated_runway': '2026-02-16T20:26:00+00:00',
#     'actual_runway': '2026-02-16T20:26:00+00:00'},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5145',
#     'iata': 'VY5145',
#     'icao': 'VLG5145',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '581',
#      'flight_iata': 'ib581',
#      'flight_icao': 'ibe581'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '34250A'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Milano Malpensa',
#     'timezone': 'Europe/Rome',
#     'iata': 'MXP',
#     'icao': 'LIMC',
#     'terminal': '1',
#     'gate': None,
#     'delay': 1,
#     'scheduled': '2026-02-16T21:55:00+00:00',
#     'estimated': '2026-02-16T21:55:00+00:00',
#     'actual': '2026-02-16T22:21:00+00:00',
#     'estimated_runway': '2026-02-16T22:21:00+00:00',
#     'actual_runway': '2026-02-16T22:21:00+00:00'},
#    'arrival': {'airport': 'El Prat De Llobregat',
#     'timezone': 'Europe/Madrid',
#     'iata': 'BCN',
#     'icao': 'LEBL',
#     'terminal': '1',
#     'gate': None,
#     'baggage': '9',
#     'scheduled': '2026-02-16T23:35:00+00:00',
#     'delay': 26,
#     'estimated': '2026-02-16T23:36:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '6337',
#     'iata': 'VY6337',
#     'icao': 'VLG6337',
#     'codeshared': None},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '344156'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Brussels Airport',
#     'timezone': 'Europe/Brussels',
#     'iata': 'BRU',
#     'icao': 'EBBR',
#     'terminal': None,
#     'gate': None,
#     'delay': 10,
#     'scheduled': '2026-02-16T19:45:00+00:00',
#     'estimated': '2026-02-16T19:45:00+00:00',
#     'actual': '2026-02-16T20:25:00+00:00',
#     'estimated_runway': '2026-02-16T20:25:00+00:00',
#     'actual_runway': '2026-02-16T20:25:00+00:00'},
#    'arrival': {'airport': 'Barajas',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAD',
#     'icao': 'LEMD',
#     'terminal': '4',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T22:10:00+00:00',
#     'delay': 40,
#     'estimated': '2026-02-16T22:20:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '5093',
#     'iata': 'VY5093',
#     'icao': 'VLG5093',
#     'codeshared': {'airline_name': 'iberia',
#      'airline_iata': 'ib',
#      'airline_icao': 'ibe',
#      'flight_number': '602',
#      'flight_iata': 'ib602',
#      'flight_icao': 'ibe602'}},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '3423C4'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Prague Vaclav Havel Airport',
#     'timezone': 'Europe/Prague',
#     'iata': 'PRG',
#     'icao': 'LKPR',
#     'terminal': '2',
#     'gate': 'D1',
#     'delay': None,
#     'scheduled': '2026-02-16T21:10:00+00:00',
#     'estimated': '2026-02-16T21:10:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'El Prat De Llobregat',
#     'timezone': 'Europe/Madrid',
#     'iata': 'BCN',
#     'icao': 'LEBL',
#     'terminal': '1',
#     'gate': None,
#     'baggage': '13',
#     'scheduled': '2026-02-16T23:40:00+00:00',
#     'delay': 59,
#     'estimated': None,
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '8655',
#     'iata': 'VY8655',
#     'icao': 'VLG8655',
#     'codeshared': None},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '345101'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'Mahon',
#     'timezone': 'Europe/Madrid',
#     'iata': 'MAH',
#     'icao': 'LEMH',
#     'terminal': None,
#     'gate': '2',
#     'delay': None,
#     'scheduled': '2026-02-16T21:30:00+00:00',
#     'estimated': '2026-02-16T21:30:00+00:00',
#     'actual': '2026-02-16T21:27:00+00:00',
#     'estimated_runway': '2026-02-16T21:27:00+00:00',
#     'actual_runway': '2026-02-16T21:27:00+00:00'},
#    'arrival': {'airport': 'El Prat De Llobregat',
#     'timezone': 'Europe/Madrid',
#     'iata': 'BCN',
#     'icao': 'LEBL',
#     'terminal': '1',
#     'gate': None,
#     'baggage': '2',
#     'scheduled': '2026-02-16T22:20:00+00:00',
#     'delay': None,
#     'estimated': '2026-02-16T22:00:00+00:00',
#     'actual': '2026-02-16T22:02:00+00:00',
#     'estimated_runway': '2026-02-16T22:02:00+00:00',
#     'actual_runway': '2026-02-16T22:02:00+00:00'},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '3725',
#     'iata': 'VY3725',
#     'icao': 'VLG3725',
#     'codeshared': None},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '345204'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'active',
#    'departure': {'airport': 'El Prat De Llobregat',
#     'timezone': 'Europe/Madrid',
#     'iata': 'BCN',
#     'icao': 'LEBL',
#     'terminal': '1',
#     'gate': 'D18',
#     'delay': None,
#     'scheduled': '2026-02-16T22:00:00+00:00',
#     'estimated': '2026-02-16T22:00:00+00:00',
#     'actual': '2026-02-16T22:16:00+00:00',
#     'estimated_runway': '2026-02-16T22:16:00+00:00',
#     'actual_runway': '2026-02-16T22:16:00+00:00'},
#    'arrival': {'airport': 'Gatwick',
#     'timezone': 'Europe/London',
#     'iata': 'LGW',
#     'icao': 'EGKK',
#     'terminal': 'S',
#     'gate': None,
#     'baggage': None,
#     'scheduled': '2026-02-16T23:20:00+00:00',
#     'delay': None,
#     'estimated': '2026-02-16T23:08:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '7842',
#     'iata': 'VY7842',
#     'icao': 'VLG7842',
#     'codeshared': None},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '3451D3'},
#    'live': None},
#   {'flight_date': '2026-02-16',
#    'flight_status': 'landed',
#    'departure': {'airport': 'El Prat De Llobregat',
#     'timezone': 'Europe/Madrid',
#     'iata': 'BCN',
#     'icao': 'LEBL',
#     'terminal': '1',
#     'gate': 'B31',
#     'delay': None,
#     'scheduled': '2026-02-16T22:00:00+00:00',
#     'estimated': '2026-02-16T22:00:00+00:00',
#     'actual': '2026-02-16T21:59:00+00:00',
#     'estimated_runway': '2026-02-16T21:59:00+00:00',
#     'actual_runway': '2026-02-16T21:59:00+00:00'},
#    'arrival': {'airport': 'Ibiza',
#     'timezone': 'Europe/Madrid',
#     'iata': 'IBZ',
#     'icao': 'LEIB',
#     'terminal': None,
#     'gate': None,
#     'baggage': '8',
#     'scheduled': '2026-02-16T22:55:00+00:00',
#     'delay': None,
#     'estimated': None,
#     'actual': '2026-02-16T22:30:00+00:00',
#     'estimated_runway': '2026-02-16T22:30:00+00:00',
#     'actual_runway': '2026-02-16T22:30:00+00:00'},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'},
#    'flight': {'number': '3512',
#     'iata': 'VY3512',
#     'icao': 'VLG3512',
#     'codeshared': None},
#    'aircraft': {'registration': None,
#     'iata': None,
#     'icao': None,
#     'icao24': '348208'},
#    'live': None}]}

# %%
r_vuelos.json()['data'][0].keys()
# Out:
# dict_keys(['flight_date', 'flight_status', 'departure', 'arrival', 'airline', 'flight', 'aircraft', 'live'])

# %% [markdown]
# ### **Ejercicio 4.**

# %% [markdown]
#  #### Convierte los datos a un DataFrame de pandas y muestra las primeras filas de DataFrame.

# %%
df_vuelos = pd.DataFrame(r_vuelos.json()['data'])

# %% [markdown]
# Vemos que valores de las columnas **departure, arrival, arrival, flight, aircraft** estan en formato JSON.

# %%
df_vuelos.head(3)
# Out:
#   flight_date flight_status  \
# 0  2026-02-17     scheduled
# 1  2026-02-17     scheduled
# 2  2026-02-16        active
#
#                                            departure  \
# 0  {'airport': 'Ben Gurion International', 'timez...
# 1  {'airport': 'El Prat De Llobregat', 'timezone'...
# 2  {'airport': 'Barajas', 'timezone': 'Europe/Mad...
#
#                                              arrival  \
# 0  {'airport': 'Barajas', 'timezone': 'Europe/Mad...
# 1  {'airport': 'Ezeiza Ministro Pistarini', 'time...
# 2  {'airport': 'Lisbon Portela', 'timezone': 'Eur...
#
#                                             airline  \
# 0  {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'}
# 1  {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'}
# 2  {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'}
#
#                                               flight  \
# 0  {'number': '5284', 'iata': 'VY5284', 'icao': '...
# 1  {'number': '9781', 'iata': 'VY9781', 'icao': '...
# 2  {'number': '5219', 'iata': 'VY5219', 'icao': '...
#
#                                             aircraft  live
# 0  {'registration': None, 'iata': None, 'icao': N...  None
# 1  {'registration': None, 'iata': None, 'icao': N...  None
# 2  {'registration': None, 'iata': None, 'icao': N...  None

# %% [markdown]
# Todas las columnas Python ha tipificado como object.

# %%
df_vuelos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   flight_date    100 non-null    object
#  1   flight_status  100 non-null    object
#  2   departure      100 non-null    object
#  3   arrival        100 non-null    object
#  4   airline        100 non-null    object
#  5   flight         100 non-null    object
#  6   aircraft       99 non-null     object
#  7   live           3 non-null      object
# dtypes: object(8)
# memory usage: 6.4+ KB

# %% [markdown]
# Vemos que casi no hay valores nulos, exepto la columa **live**.

# %%
null_counts = df_vuelos.isnull().sum()

null_porcentaje = (null_counts / len(df_vuelos)) * 100

null_info = pd.DataFrame({
    'columna': null_counts.index,
    'nulos': null_counts.values,
    'Porcenraje de nulos': null_porcentaje
})

null_info
# Out:
#                      columna  nulos  Porcenraje de nulos
# flight_date      flight_date      0                  0.0
# flight_status  flight_status      0                  0.0
# departure          departure      0                  0.0
# arrival              arrival      0                  0.0
# airline              airline      0                  0.0
# flight                flight      0                  0.0
# aircraft            aircraft      1                  1.0
# live                    live     97                 97.0

# %% [markdown]
# Aplicamos el metodo json_normalize a dataframes **df_salidas, df_llegadas, df_aerolinias, df_flights y df_aeronaves** para convertir las claves de objeto JSON a las columnas.

# %%
df_salidas = pd.json_normalize(df_vuelos.departure).add_prefix('departure_')
df_salidas.head(3)
# Out:
#           departure_airport departure_timezone departure_iata departure_icao  \
# 0  Ben Gurion International     Asia/Jerusalem            TLV           LLBG
# 1      El Prat De Llobregat      Europe/Madrid            BCN           LEBL
# 2                   Barajas      Europe/Madrid            MAD           LEMD
#
#   departure_terminal departure_gate  departure_delay  \
# 0                  3           None              NaN
# 1                  1              D              NaN
# 2                  4           None              NaN
#
#          departure_scheduled        departure_estimated departure_actual  \
# 0  2026-02-17T06:00:00+00:00  2026-02-17T06:00:00+00:00             None
# 1  2026-02-17T01:30:00+00:00  2026-02-17T01:30:00+00:00             None
# 2  2026-02-16T23:00:00+00:00  2026-02-16T23:00:00+00:00             None
#
#   departure_estimated_runway departure_actual_runway
# 0                       None                    None
# 1                       None                    None
# 2                       None                    None

# %%
df_llegadas = pd.json_normalize(df_vuelos.arrival).add_prefix('arrival_')
df_llegadas.head(3)
# Out:
#              arrival_airport                arrival_timezone arrival_iata  \
# 0                    Barajas                   Europe/Madrid          MAD
# 1  Ezeiza Ministro Pistarini  America/Argentina/Buenos_Aires          EZE
# 2             Lisbon Portela                   Europe/Lisbon          LIS
#
#   arrival_icao arrival_terminal arrival_gate arrival_baggage  \
# 0         LEMD               4S         None            None
# 1         SAEZ               IA         None            None
# 2         LPPT                1         None            None
#
#            arrival_scheduled  arrival_delay arrival_estimated arrival_actual  \
# 0  2026-02-17T10:30:00+00:00           15.0              None           None
# 1  2026-02-17T11:10:00+00:00            NaN              None           None
# 2  2026-02-16T23:25:00+00:00           18.0              None           None
#
#   arrival_estimated_runway arrival_actual_runway
# 0                     None                  None
# 1                     None                  None
# 2                     None                  None

# %%
df_aerolinias = pd.json_normalize(df_vuelos.airline).add_prefix('airline_')
df_aerolinias.head(3)
# Out:
#   airline_name airline_iata airline_icao
# 0      Vueling           VY          VLG
# 1      Vueling           VY          VLG
# 2      Vueling           VY          VLG

# %%
df_flights = pd.json_normalize(df_vuelos.flight).add_prefix('flight_')
df_flights.head(3)
# Out:
#   flight_number flight_iata flight_icao flight_codeshared.airline_name  \
# 0          5284      VY5284     VLG5284                 iberia express
# 1          9781      VY9781     VLG9781                          level
# 2          5219      VY5219     VLG5219                         iberia
#
#   flight_codeshared.airline_iata flight_codeshared.airline_icao  \
# 0                             i2                            ibs
# 1                             ll                            lvl
# 2                             ib                            ibe
#
#   flight_codeshared.flight_number flight_codeshared.flight_iata  \
# 0                            1874                        i21874
# 1                            2601                        ll2601
# 2                             539                         ib539
#
#   flight_codeshared.flight_icao  flight_codeshared
# 0                       ibs1874                NaN
# 1                       lvl2601                NaN
# 2                        ibe539                NaN

# %%
df_aeronaves = pd.json_normalize(df_vuelos['aircraft']).add_prefix('aircraft')
df_aeronaves.head(3)
# Out:
#   aircraftregistration aircraftiata aircrafticao aircrafticao24
# 0                 None         None         None         347247
# 1                 None         None         None         346605
# 2                 None         None         None         3423C4

# %% [markdown]
# Unimos los datafames creados al unico.

# %%
df_vuelos_total = pd.concat([df_salidas, df_llegadas, df_aerolinias, df_flights, df_aeronaves], axis=1)
df_vuelos_total.head(5)
# Out:
#                          departure_airport departure_timezone departure_iata  \
# 0                 Ben Gurion International     Asia/Jerusalem            TLV
# 1                     El Prat De Llobregat      Europe/Madrid            BCN
# 2                                  Barajas      Europe/Madrid            MAD
# 3  Blaise Diagne International Airport\r\n               None            DSS
# 4                                  Barajas      Europe/Madrid            MAD
#
#   departure_icao departure_terminal departure_gate  departure_delay  \
# 0           LLBG                  3           None              NaN
# 1           LEBL                  1              D              NaN
# 2           LEMD                  4           None              NaN
# 3           GOBD               None           None              1.0
# 4           LEMD                  4           None              NaN
#
#          departure_scheduled        departure_estimated  \
# 0  2026-02-17T06:00:00+00:00  2026-02-17T06:00:00+00:00
# 1  2026-02-17T01:30:00+00:00  2026-02-17T01:30:00+00:00
# 2  2026-02-16T23:00:00+00:00  2026-02-16T23:00:00+00:00
# 3  2026-02-16T20:35:00+00:00  2026-02-16T20:35:00+00:00
# 4  2026-02-16T21:40:00+00:00  2026-02-16T21:40:00+00:00
#
#             departure_actual  ... flight_codeshared.airline_iata  \
# 0                       None  ...                             i2
# 1                       None  ...                             ll
# 2                       None  ...                             ib
# 3  2026-02-16T20:53:00+00:00  ...                            NaN
# 4  2026-02-16T22:13:00+00:00  ...                             ib
#
#   flight_codeshared.airline_icao flight_codeshared.flight_number  \
# 0                            ibs                            1874
# 1                            lvl                            2601
# 2                            ibe                             539
# 3                            NaN                             NaN
# 4                            ibe                             591
#
#   flight_codeshared.flight_iata flight_codeshared.flight_icao  \
# 0                        i21874                       ibs1874
# 1                        ll2601                       lvl2601
# 2                         ib539                        ibe539
# 3                           NaN                           NaN
# 4                         ib591                        ibe591
#
#   flight_codeshared aircraftregistration aircraftiata aircrafticao  \
# 0               NaN                 None         None         None
# 1               NaN                 None         None         None
# 2               NaN                 None         None         None
# 3               NaN               EC-MFN         A320         A320
# 4               NaN                 None         None         None
#
#   aircrafticao24
# 0         347247
# 1         346605
# 2         3423C4
# 3         344697
# 4         34134D
#
# [5 rows x 42 columns]

# %%
print(df_vuelos_total.columns)
# Out:
# Index(['departure_airport', 'departure_timezone', 'departure_iata',
#        'departure_icao', 'departure_terminal', 'departure_gate',
#        'departure_delay', 'departure_scheduled', 'departure_estimated',
#        'departure_actual', 'departure_estimated_runway',
#        'departure_actual_runway', 'arrival_airport', 'arrival_timezone',
#        'arrival_iata', 'arrival_icao', 'arrival_terminal', 'arrival_gate',
#        'arrival_baggage', 'arrival_scheduled', 'arrival_delay',
#        'arrival_estimated', 'arrival_actual', 'arrival_estimated_runway',
#        'arrival_actual_runway', 'airline_name', 'airline_iata', 'airline_icao',
#        'flight_number', 'flight_iata', 'flight_icao',
#        'flight_codeshared.airline_name', 'flight_codeshared.airline_iata',
#        'flight_codeshared.airline_icao', 'flight_codeshared.flight_number',
#        'flight_codeshared.flight_iata', 'flight_codeshared.flight_icao',
#        'flight_codeshared', 'aircraftregistration', 'aircraftiata',
#        'aircrafticao', 'aircrafticao24'],
#       dtype='object')

# %% [markdown]
# ### **Nivel 3**

# %% [markdown]
# ### **Ejercicio 1.**

# %% [markdown]
# #### Utiliza la API de Open Data BCN para Buscar un dataset de tu interés mediante package_search y package_show.

# %% [markdown]
# Miramos la lista dels datasets usando **package_search**.

# %%
url_bcn = 'https://opendata-ajuntament.barcelona.cat/data/api/action/package_search'

params = {'q': '*:*', 'rows': 10}

r_openBCN = requests.get(url_bcn, params=params)

if r_openBCN.status_code == 200:
    resultados = r_openBCN.json()['result']['results']
    for ds in resultados:
        print(f"Título: {ds['title']} | ID: {ds['name']}")
# Out:
# Título: Fees excluding VAT from the public price register for waste collection (excluding large producers) of the Barcelona City Council | ID: rebuts-quota-padro-residus-bcn
# Título: Receipts and quota of the register of the Vados Tax of the Barcelona City Council | ID: rebuts-quota-padro-guals
# Título: Receipts and charges from the motor vehicle tax roll of the Barcelona City Council | ID: rebuts-quota-padro-vehicle-bcn
# Título: Immigrants | ID: pad_imm_mdbas
# Título: Emigrants | ID: pad_emi_mdbas
# Título: Cancellations for undue inscription | ID: pad_bai_mdbas
# Título: Registrations by omission | ID: pad_alt_mdbas
# Título: Deaths | ID: pad_def_mdbas
# Título: Births | ID: pad_nai_mdbas
# Título: Population by geographical region of nationality and sex | ID: pad_mdb_nacionalitat-regio_sexe

# %% [markdown]
# Hacemos una búsqueda más concreta, por ejemplo los nombres más populares.

# %%
params = {'q': 'Most popular names', 'rows': 10}

r_openBCN = requests.get(url_bcn, params=params)

if r_openBCN.status_code == 200:
    results = r_openBCN.json()['result']['results']
    for ds in results:
        print(f"Título: {ds['title']} | {ds['id']} |  ID: {ds['name']}")
# Out:
# Título: Most popular names by sex and decade of birth | 769a7f14-3353-4b74-b35c-8abfc20e357c |  ID: pad_m_nom_decada_sexe

# %% [markdown]
# ### **Ejercicio 2.**

# %% [markdown]
# ####  De los resultados obtenidos, selecciona uno que tenga recursos disponibles en CSV o JSON.

# %% [markdown]
# Eligimos el dataset con **ID pad_m_nom_decada_sexe** para mirar los nombres más populares del año 2025.

# %%
id_dataset = 'pad_m_nom_decada_sexe'

# %% [markdown]
# ### **Ejercicio 3.**

# %% [markdown]
# #### Con el resource_id del recurso seleccionado, realiza una consulta mediante datastore_search para recuperar al menos 100 registros.

# %%
url = 'https://opendata-ajuntament.barcelona.cat/data/api/3/action/package_show'

params = {
    'id': id_dataset,
}

response = requests.get(url, params=params)
data = response.json()

resultados = data['result']['resources']

for res in resultados:
    print(res['id'], res['name'])
# Out:
# 7446b652-c26a-4137-8f5a-f0fa432adb1d 2025_pad_m_nom_decada_sexe.csv
# 274a2e37-5986-4899-a86a-9f7441aac16a 2025_pad_m_nom_decada_sexe.json
# 5a9505b8-4baa-4b37-a38e-4d2a78df040e 2024_pad_m_nom_decada_sexe.csv
# 810d1d41-aaae-48db-8e23-93870bbebaa0 2024_pad_m_nom_decada_sexe.json
# 5434e6bf-64f3-4c49-b9f9-0d715b28ecc4 2023_pad_m_nom_decada_sexe.csv
# b81617ef-7100-4f7d-b0b8-7059a17aed9b 2023_pad_m_nom_decada_sexe.json
# b006ea5f-b822-4ce3-8cea-df6533cff364 2022_pad_m_nom_decada_sexe.csv
# 75a6c9ad-7c01-4f63-9020-17630a786645 2022_pad_m_nom_decada_sexe.json
# 7aaf61c6-69f7-4246-8086-39a1fabb7fc8 2021_pad_m_nom_decada_sexe.csv
# 558b56bc-6192-4687-9531-db1bdcc67a95 2021_pad_m_nom_decada_sexe.json
# d4bb5830-cd77-451d-89b6-ba96b36eab26 2020_pad_m_nom_decada_sexe.csv
# 9e8debd4-fc24-4603-acf2-d12c58c86eca 2020_pad_m_nom_decada_sexe.json
# 7e182c65-4647-4b45-93dc-900f63ae4c74 2019_pad_m_nom_decada_sexe.csv
# 8cf16484-8e38-41dc-8dd0-f49ffb5c505d 2019_pad_m_nom_decada_sexe.json
# a68eacd3-8195-463e-85b4-b486b0d222ac 2018_pad_m_nom_decada_sexe.csv
# 1d05379a-af54-4d72-b112-8ae88ef53591 2018_pad_m_nom_decada_sexe.json
# 9ae683b2-751d-41df-b07f-86bc2b084469 2017_pad_m_nom_decada_sexe.csv
# d096859c-9658-451c-a1a1-c16376f48a32 2017_pad_m_nom_decada_sexe.json
# 99a0c564-3f23-4357-9e3b-ca8fe6f81f9d 2016_pad_m_nom_decada_sexe.csv
# bb04652f-7991-4bb9-aa3b-617c963583d3 2016_pad_m_nom_decada_sexe.json
# aa5be5c0-50fd-48dc-97cf-8de92c82e532 2015_pad_m_nom_decada_sexe.csv
# 9b4a5226-e8e6-4092-b977-b47931f45da9 2015_pad_m_nom_decada_sexe.json
# 863d6b11-0e9b-4515-91e4-cf5742fecb51 2014_pad_m_nom_decada_sexe.csv
# e1d99d5d-fd03-4d90-9e58-703f43df9ea4 2014_pad_m_nom_decada_sexe.json
# 9ed13eb3-d3af-4f56-a307-9e169fbb2740 2013_pad_m_nom_decada_sexe.csv
# df519742-3304-4d4d-914f-2dae5a9f879b 2013_pad_m_nom_decada_sexe.json
# e3967a40-ff8f-4d4a-b0da-6c78d5f5d186 2012_pad_m_nom_decada_sexe.csv
# 843bbc08-da0f-4c9c-bfcb-7e68b71f5a7b 2012_pad_m_nom_decada_sexe.json
# b7c39e4a-6afd-442e-bb56-507fcab75222 2011_pad_m_nom_decada_sexe.csv
# a26a4a59-180d-4a01-a235-cea6341078a6 2011_pad_m_nom_decada_sexe.json
# be1c2331-056b-43f3-844e-c6da71831205 2010_pad_m_nom_decada_sexe.csv
# 6b3d140d-a632-475d-ba52-f065ed902334 2010_pad_m_nom_decada_sexe.json
# eabc4ae1-8801-4927-80c4-b287fae315fb 2009_pad_m_nom_decada_sexe.csv
# 7d9a60bc-c8ee-4c95-b76e-3435aceaaf04 2009_pad_m_nom_decada_sexe.json
# 5a3eb64c-a803-4390-a99d-62ad79dc3b89 2008_pad_m_nom_decada_sexe.csv
# a5838eb6-630e-460d-b0e9-e64bcefc26f7 2008_pad_m_nom_decada_sexe.json
# 97a0625c-4bf5-4ed6-9721-444ca754a0a3 2007_pad_m_nom_decada_sexe.csv
# 6b12ebbc-76dd-43e9-9051-bc3b18b6d0be 2007_pad_m_nom_decada_sexe.json
# 6a4f3ae9-ba00-4a27-be8a-c6c62540cbc7 2006_pad_m_nom_decada_sexe.csv
# 63107c69-bd62-4ac1-afd2-8b52b0f35c62 2006_pad_m_nom_decada_sexe.json
# 41dee2e6-12fd-46fd-9625-b45f7b2c8640 2005_pad_m_nom_decada_sexe.csv
# 1e18b4ec-f611-4b9a-b3d9-b8158f6cf620 2005_pad_m_nom_decada_sexe.json
# ce77ada3-843f-4650-8a75-eedd9ac8e3fb 2004_pad_m_nom_decada_sexe.csv
# 9a2bac00-5fa6-401f-b899-ff67f1326787 2004_pad_m_nom_decada_sexe.json
# 01909757-79f0-4bef-b22e-5cacb210b0cd 2003_pad_m_nom_decada_sexe.csv
# bebb6d10-b111-4ade-8029-1d1c0637aabe 2003_pad_m_nom_decada_sexe.json
# 27ccb29c-0314-4eb1-a4a8-7eab5c5f0a6d 2002_pad_m_nom_decada_sexe.csv
# ee6a0f9b-2227-4911-88c3-a1e16dba0c20 2002_pad_m_nom_decada_sexe.json
# 1a76cce8-fffb-4daa-beff-af265b2b9f5c 2001_pad_m_nom_decada_sexe.csv
# 4d79e1ca-bd73-4d64-a225-a7c8578f261a 2001_pad_m_nom_decada_sexe.json
# 39a7fef5-f125-4961-800f-d309c58b1ac6 2000_pad_m_nom_decada_sexe.csv
# de3cb4d4-91ee-4134-8e99-5b21c2462849 2000_pad_m_nom_decada_sexe.json
# a88df607-b52c-4626-98e7-0be15638f518 1999_pad_m_nom_decada_sexe.csv
# 7e7efd07-615f-4e44-8771-39a5805b57e3 1999_pad_m_nom_decada_sexe.json
# 42659624-ee77-4cd9-92f6-80d27c5f20eb 1998_pad_m_nom_decada_sexe.csv
# 88872758-f381-4c8c-ad7b-c7a9b8ef3e3a 1998_pad_m_nom_decada_sexe.json
# ab9a7eba-cc68-4823-83ce-e7aa4f5c51bc 1997_pad_m_nom_decada_sexe.csv
# 93a784c1-74f7-416e-bd55-41c93ccf575b 1997_pad_m_nom_decada_sexe.json

# %% [markdown]
# ### **Ejercicio 3.**

# %% [markdown]
# #### Con el resource_id del recurso seleccionado, realiza una consulta mediante datastore_search para recuperar al menos 100 registros.

# %% [markdown]
# Eligimos el primero recurso con id 7446b652-c26a-4137-8f5a-f0fa432adb1d

# %%
url_recurso =' https://opendata-ajuntament.barcelona.cat/data/api/action/datastore_search?resource_id=7446b652-c26a-4137-8f5a-f0fa432adb1d'

r_recurso = requests.get(url_recurso)

# %%
r_recurso.json()['result']['records']
# Out:
# [{'NOM': 'MONTSERRAT',
#   'SEXE': '1',
#   'Valor': '3976',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '5',
#   '_id': 1},
#  {'NOM': 'DAVID',
#   'SEXE': '2',
#   'Valor': '3922',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '6',
#   '_id': 2},
#  {'NOM': 'MONTSERRAT',
#   'SEXE': '1',
#   'Valor': '3515',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '4',
#   '_id': 3},
#  {'NOM': 'JOSE',
#   'SEXE': '2',
#   'Valor': '3169',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '3',
#   '_id': 4},
#  {'NOM': 'JORDI',
#   'SEXE': '2',
#   'Valor': '3130',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '6',
#   '_id': 5},
#  {'NOM': 'MARTA',
#   'SEXE': '1',
#   'Valor': '3062',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '6',
#   '_id': 6},
#  {'NOM': 'ANTONIO',
#   'SEXE': '2',
#   'Valor': '3047',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '4',
#   '_id': 7},
#  {'NOM': 'ANTONIO',
#   'SEXE': '2',
#   'Valor': '2904',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '3',
#   '_id': 8},
#  {'NOM': 'JOSE',
#   'SEXE': '2',
#   'Valor': '2861',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '4',
#   '_id': 9},
#  {'NOM': 'M CARMEN',
#   'SEXE': '1',
#   'Valor': '2693',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '4',
#   '_id': 10},
#  {'NOM': 'JORDI',
#   'SEXE': '2',
#   'Valor': '2676',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '5',
#   '_id': 11},
#  {'NOM': 'ANTONIO',
#   'SEXE': '2',
#   'Valor': '2635',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '5',
#   '_id': 12},
#  {'NOM': 'CARMEN',
#   'SEXE': '1',
#   'Valor': '2619',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '3',
#   '_id': 13},
#  {'NOM': 'LAURA',
#   'SEXE': '1',
#   'Valor': '2595',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '8',
#   '_id': 14},
#  {'NOM': 'CRISTINA',
#   'SEXE': '1',
#   'Valor': '2534',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '6',
#   '_id': 15},
#  {'NOM': 'DAVID',
#   'SEXE': '2',
#   'Valor': '2514',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '7',
#   '_id': 16},
#  {'NOM': 'MARC',
#   'SEXE': '2',
#   'Valor': '2485',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '8',
#   '_id': 17},
#  {'NOM': 'LAURA',
#   'SEXE': '1',
#   'Valor': '2447',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '7',
#   '_id': 18},
#  {'NOM': 'MARIA',
#   'SEXE': '1',
#   'Valor': '2437',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '8',
#   '_id': 19},
#  {'NOM': 'MARTA',
#   'SEXE': '1',
#   'Valor': '2408',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '7',
#   '_id': 20},
#  {'NOM': 'NURIA',
#   'SEXE': '1',
#   'Valor': '2360',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '5',
#   '_id': 21},
#  {'NOM': 'MONICA',
#   'SEXE': '1',
#   'Valor': '2357',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '6',
#   '_id': 22},
#  {'NOM': 'MANUEL',
#   'SEXE': '2',
#   'Valor': '2334',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '4',
#   '_id': 23},
#  {'NOM': 'M CARMEN',
#   'SEXE': '1',
#   'Valor': '2286',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '3',
#   '_id': 24},
#  {'NOM': 'MARIA',
#   'SEXE': '1',
#   'Valor': '2282',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '3',
#   '_id': 25},
#  {'NOM': 'DANIEL',
#   'SEXE': '2',
#   'Valor': '2281',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '6',
#   '_id': 26},
#  {'NOM': 'FRANCISCO',
#   'SEXE': '2',
#   'Valor': '2280',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '4',
#   '_id': 27},
#  {'NOM': 'MARC',
#   'SEXE': '2',
#   'Valor': '2248',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '9',
#   '_id': 28},
#  {'NOM': 'MONTSERRAT',
#   'SEXE': '1',
#   'Valor': '2242',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '3',
#   '_id': 29},
#  {'NOM': 'MARIA',
#   'SEXE': '1',
#   'Valor': '2178',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '2',
#   '_id': 30},
#  {'NOM': 'MANUEL',
#   'SEXE': '2',
#   'Valor': '2161',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '3',
#   '_id': 31},
#  {'NOM': 'FRANCISCO',
#   'SEXE': '2',
#   'Valor': '2160',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '3',
#   '_id': 32},
#  {'NOM': 'DANIEL',
#   'SEXE': '2',
#   'Valor': '2139',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '7',
#   '_id': 33},
#  {'NOM': 'JORGE',
#   'SEXE': '2',
#   'Valor': '2095',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '5',
#   '_id': 34},
#  {'NOM': 'CARLOS',
#   'SEXE': '2',
#   'Valor': '2088',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '6',
#   '_id': 35},
#  {'NOM': 'CARMEN',
#   'SEXE': '1',
#   'Valor': '2069',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '4',
#   '_id': 36},
#  {'NOM': 'JAVIER',
#   'SEXE': '2',
#   'Valor': '2069',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '6',
#   '_id': 37},
#  {'NOM': 'MARTA',
#   'SEXE': '1',
#   'Valor': '2064',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '8',
#   '_id': 38},
#  {'NOM': 'CARLOS',
#   'SEXE': '2',
#   'Valor': '2060',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '5',
#   '_id': 39},
#  {'NOM': 'CRISTINA',
#   'SEXE': '1',
#   'Valor': '2056',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '7',
#   '_id': 40},
#  {'NOM': 'M CARMEN',
#   'SEXE': '1',
#   'Valor': '2009',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '5',
#   '_id': 41},
#  {'NOM': 'OSCAR',
#   'SEXE': '2',
#   'Valor': '1988',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '6',
#   '_id': 42},
#  {'NOM': 'JUAN',
#   'SEXE': '2',
#   'Valor': '1973',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '3',
#   '_id': 43},
#  {'NOM': 'SILVIA',
#   'SEXE': '1',
#   'Valor': '1969',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '6',
#   '_id': 44},
#  {'NOM': 'MARTA',
#   'SEXE': '1',
#   'Valor': '1957',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '5',
#   '_id': 45},
#  {'NOM': 'MARIA',
#   'SEXE': '1',
#   'Valor': '1934',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '9',
#   '_id': 46},
#  {'NOM': 'MANUEL',
#   'SEXE': '2',
#   'Valor': '1930',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '5',
#   '_id': 47},
#  {'NOM': 'JUAN',
#   'SEXE': '2',
#   'Valor': '1915',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '4',
#   '_id': 48},
#  {'NOM': 'MONTSERRAT',
#   'SEXE': '1',
#   'Valor': '1913',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '6',
#   '_id': 49},
#  {'NOM': 'LAURA',
#   'SEXE': '1',
#   'Valor': '1900',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '6',
#   '_id': 50},
#  {'NOM': 'JOSE',
#   'SEXE': '2',
#   'Valor': '1899',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '5',
#   '_id': 51},
#  {'NOM': 'CARMEN',
#   'SEXE': '1',
#   'Valor': '1896',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '2',
#   '_id': 52},
#  {'NOM': 'JORDI',
#   'SEXE': '2',
#   'Valor': '1895',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '7',
#   '_id': 53},
#  {'NOM': 'ANNA',
#   'SEXE': '1',
#   'Valor': '1893',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '8',
#   '_id': 54},
#  {'NOM': 'DAVID',
#   'SEXE': '2',
#   'Valor': '1873',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '8',
#   '_id': 55},
#  {'NOM': 'NURIA',
#   'SEXE': '1',
#   'Valor': '1873',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '6',
#   '_id': 56},
#  {'NOM': 'FRANCISCO',
#   'SEXE': '2',
#   'Valor': '1863',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '5',
#   '_id': 57},
#  {'NOM': 'SONIA',
#   'SEXE': '1',
#   'Valor': '1858',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '6',
#   '_id': 58},
#  {'NOM': 'SERGIO',
#   'SEXE': '2',
#   'Valor': '1818',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '6',
#   '_id': 59},
#  {'NOM': 'JOSEFA',
#   'SEXE': '1',
#   'Valor': '1814',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '3',
#   '_id': 60},
#  {'NOM': 'SANDRA',
#   'SEXE': '1',
#   'Valor': '1790',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '6',
#   '_id': 61},
#  {'NOM': 'DANIEL',
#   'SEXE': '2',
#   'Valor': '1782',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '8',
#   '_id': 62},
#  {'NOM': 'EVA',
#   'SEXE': '1',
#   'Valor': '1749',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '6',
#   '_id': 63},
#  {'NOM': 'ANNA',
#   'SEXE': '1',
#   'Valor': '1742',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '7',
#   '_id': 64},
#  {'NOM': 'JORGE',
#   'SEXE': '2',
#   'Valor': '1737',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '6',
#   '_id': 65},
#  {'NOM': 'MARC',
#   'SEXE': '2',
#   'Valor': '1732',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '7',
#   '_id': 66},
#  {'NOM': 'M TERESA',
#   'SEXE': '1',
#   'Valor': '1730',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '4',
#   '_id': 67},
#  {'NOM': 'CRISTINA',
#   'SEXE': '1',
#   'Valor': '1729',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '5',
#   '_id': 68},
#  {'NOM': 'ISABEL',
#   'SEXE': '1',
#   'Valor': '1683',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '4',
#   '_id': 69},
#  {'NOM': 'ANTONIO',
#   'SEXE': '2',
#   'Valor': '1651',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '6',
#   '_id': 70},
#  {'NOM': 'JAVIER',
#   'SEXE': '2',
#   'Valor': '1649',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '5',
#   '_id': 71},
#  {'NOM': 'M TERESA',
#   'SEXE': '1',
#   'Valor': '1633',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '3',
#   '_id': 72},
#  {'NOM': 'ANDREA',
#   'SEXE': '1',
#   'Valor': '1627',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '8',
#   '_id': 73},
#  {'NOM': 'JAVIER',
#   'SEXE': '2',
#   'Valor': '1607',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '7',
#   '_id': 74},
#  {'NOM': 'ALEX',
#   'SEXE': '2',
#   'Valor': '1597',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '9',
#   '_id': 75},
#  {'NOM': 'MARIA',
#   'SEXE': '1',
#   'Valor': '1575',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '7',
#   '_id': 76},
#  {'NOM': 'ANA MARIA',
#   'SEXE': '1',
#   'Valor': '1571',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '5',
#   '_id': 77},
#  {'NOM': 'PILAR',
#   'SEXE': '1',
#   'Valor': '1542',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '3',
#   '_id': 78},
#  {'NOM': 'SILVIA',
#   'SEXE': '1',
#   'Valor': '1541',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '5',
#   '_id': 79},
#  {'NOM': 'MARIA',
#   'SEXE': '1',
#   'Valor': '1538',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '4',
#   '_id': 80},
#  {'NOM': 'PAULA',
#   'SEXE': '1',
#   'Valor': '1534',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '9',
#   '_id': 81},
#  {'NOM': 'SUSANA',
#   'SEXE': '1',
#   'Valor': '1534',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '6',
#   '_id': 82},
#  {'NOM': 'MARC',
#   'SEXE': '2',
#   'Valor': '1528',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '10',
#   '_id': 83},
#  {'NOM': 'ISABEL',
#   'SEXE': '1',
#   'Valor': '1527',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '3',
#   '_id': 84},
#  {'NOM': 'CARLOS',
#   'SEXE': '2',
#   'Valor': '1520',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '7',
#   '_id': 85},
#  {'NOM': 'POL',
#   'SEXE': '2',
#   'Valor': '1501',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '9',
#   '_id': 86},
#  {'NOM': 'JORDI',
#   'SEXE': '2',
#   'Valor': '1487',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '4',
#   '_id': 87},
#  {'NOM': 'JOSE',
#   'SEXE': '2',
#   'Valor': '1481',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '2',
#   '_id': 88},
#  {'NOM': 'PAU',
#   'SEXE': '2',
#   'Valor': '1466',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '9',
#   '_id': 89},
#  {'NOM': 'ALEJANDRO',
#   'SEXE': '2',
#   'Valor': '1453',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '8',
#   '_id': 90},
#  {'NOM': 'LAIA',
#   'SEXE': '1',
#   'Valor': '1451',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '9',
#   '_id': 91},
#  {'NOM': 'JULIA',
#   'SEXE': '1',
#   'Valor': '1420',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '9',
#   '_id': 92},
#  {'NOM': 'ISABEL',
#   'SEXE': '1',
#   'Valor': '1417',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '5',
#   '_id': 93},
#  {'NOM': 'CRISTINA',
#   'SEXE': '1',
#   'Valor': '1410',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '8',
#   '_id': 94},
#  {'NOM': 'JUAN',
#   'SEXE': '2',
#   'Valor': '1396',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '5',
#   '_id': 95},
#  {'NOM': 'YOLANDA',
#   'SEXE': '1',
#   'Valor': '1388',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '6',
#   '_id': 96},
#  {'NOM': 'PAULA',
#   'SEXE': '1',
#   'Valor': '1385',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '8',
#   '_id': 97},
#  {'NOM': 'FRANCISCO JAVIER',
#   'SEXE': '2',
#   'Valor': '1366',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '5',
#   '_id': 98},
#  {'NOM': 'ALBERT',
#   'SEXE': '2',
#   'Valor': '1364',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '7',
#   '_id': 99},
#  {'NOM': 'MERCEDES',
#   'SEXE': '1',
#   'Valor': '1357',
#   'Data_Referencia': '2025-01-01T00:00:00',
#   'DECADA': '4',
#   '_id': 100}]

# %% [markdown]
# ### **Ejercicio 4.**

# %% [markdown]
# #### Convierte los resultados a un DataFrame.

# %%
df_nombres_2025= pd.DataFrame(r_recurso.json()['result']['records'])
df_nombres_2025.head(10)
# Out:
#           NOM SEXE Valor      Data_Referencia DECADA  _id
# 0  MONTSERRAT    1  3976  2025-01-01T00:00:00      5    1
# 1       DAVID    2  3922  2025-01-01T00:00:00      6    2
# 2  MONTSERRAT    1  3515  2025-01-01T00:00:00      4    3
# 3        JOSE    2  3169  2025-01-01T00:00:00      3    4
# 4       JORDI    2  3130  2025-01-01T00:00:00      6    5
# 5       MARTA    1  3062  2025-01-01T00:00:00      6    6
# 6     ANTONIO    2  3047  2025-01-01T00:00:00      4    7
# 7     ANTONIO    2  2904  2025-01-01T00:00:00      3    8
# 8        JOSE    2  2861  2025-01-01T00:00:00      4    9
# 9    M CARMEN    1  2693  2025-01-01T00:00:00      4   10

# %% [markdown]
# ### **Ejercicio 5.**

# %% [markdown]
# #### Guarda DataFrame en un archivo .csv.

# %%
df_nombres_2025.to_csv('Nombres populares en el año 2025.csv')
